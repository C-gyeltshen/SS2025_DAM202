# %% [markdown]
# # Practical 2
# ## Section 1: Connecting the Google Drive to read dataset

# %%
import os

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
os.chdir('/content/drive/MyDrive/practical/practical_2')

# %%
os.listdir()
# Out:
# ['practical_2.ipynb']

# %%
ROOT = "/content/drive/MyDrive/practical_data"
import os
os.chdir(ROOT)

# %%
#import os
os.listdir()
# Out:
# ['text.txt', 'my_word2vec_model.model']

# %%
with open('text.txt', 'r', encoding='utf-8') as f: # Remember your data set path should be specified if not in same working directory
    texts = f.readlines()

# %%
texts[:30]
# Out:
# ["                ALICE'S ADVENTURES IN WONDERLAND\n",
#  '\n',
#  '                          Lewis Carroll\n',
#  '\n',
#  '               THE MILLENNIUM FULCRUM EDITION 3.0\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '                            CHAPTER I\n',
#  '\n',
#  '                      Down the Rabbit-Hole\n',
#  '\n',
#  '\n',
#  '  Alice was beginning to get very tired of sitting by her sister\n',
#  'on the bank, and of having nothing to do:  once or twice she had\n',
#  'peeped into the book her sister was reading, but it had no\n',
#  "pictures or conversations in it, `and what is the use of a book,'\n",
#  "thought Alice `without pictures or conversation?'\n",
#  '\n',
#  '  So she was considering in her own mind (as well as she could,\n',
#  'for the hot day made her feel very sleepy and stupid), whether\n',
#  'the pleasure of making a daisy-chain would be worth the trouble\n',
#  'of getting up and picking the daisies, when suddenly a White\n',
#  'Rabbit with pink eyes ran close by her.\n',
#  '\n',
#  '  There was nothing so VERY remarkable in that; nor did Alice\n',
#  'think it so VERY much out of the way to hear the Rabbit say to\n',
#  "itself, `Oh dear!  Oh dear!  I shall be late!'  (when she thought\n",
#  'it over afterwards, it occurred to her that she ought to have\n']

# %% [markdown]
# It calculates key metrics such as
# *   Vocabulary size
# *  Average sentence length
# *   word frequencies
# - Vocabulary diversity and the ratio of rare words

# %%
def assess_data_quality(texts):
    """Analyze text data quality for Word2Vec training"""

    stats = {
        'total_documents': len(texts),
        'total_words': 0,
        'unique_words': set(),
        'sentence_lengths': [],
        'word_frequencies': {}
    }

    for text in texts:
        words = text.lower().split()
        stats['total_words'] += len(words)
        stats['sentence_lengths'].append(len(words))
        stats['unique_words'].update(words)

        for word in words:
            stats['word_frequencies'][word] = stats['word_frequencies'].get(word, 0) + 1

    stats['vocabulary_size'] = len(stats['unique_words'])
    stats['avg_sentence_length'] = sum(stats['sentence_lengths']) / len(stats['sentence_lengths'])

    # Find most common words
    sorted_words = sorted(stats['word_frequencies'].items(), key=lambda x: x[1], reverse=True)
    stats['top_words'] = sorted_words[:20]

    # Quality indicators
    stats['quality_score'] = {
        'vocabulary_diversity': stats['vocabulary_size'] / stats['total_words'],
        'avg_word_frequency': stats['total_words'] / stats['vocabulary_size'],
        'rare_words_ratio': sum(1 for count in stats['word_frequencies'].values() if count == 1) / stats['vocabulary_size']
    }

    return stats

# Example usage
quality_report = assess_data_quality(texts)
print(f"Total documents: {quality_report['total_documents']:,}")
print(f"Vocabulary size: {quality_report['vocabulary_size']:,}")
# print(f"Unique Words: {quality_report['unique_words']}")
print(f"Average sentence length: {quality_report['avg_sentence_length']:.1f}")
print(f"Vocabulary diversity: {quality_report['quality_score']['vocabulary_diversity']:.4f}")
# Out:
# Total documents: 3,598
# Vocabulary size: 4,950
# Average sentence length: 7.4
# Vocabulary diversity: 0.1870

# %% [markdown]
#  Setting up **Python environment** for **natural language processing** (NLP) tasks

# %%
#Import Packages
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
import nltk

# %% [markdown]
# Download required **NLTK data**

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ## Section 2: Data preprocessing
#
# Performing basic preprocessing like
# - Lowering the text case
# - Remove punctuation and number
# - Remove stopwords
# - Lemmatize, remove url and email

# %%
class AdvancedTextPreprocessor:
    """Comprehensive text preprocessing for Word2Vec training"""

    def __init__(self,
                 lowercase=True,
                 remove_punctuation=True,
                 remove_numbers=False,
                 remove_stopwords=False,
                 min_word_length=2,
                 max_word_length=50,
                 lemmatize=False,
                 remove_urls=True,
                 remove_emails=True,
                 keep_sentences=True):

        self.lowercase = lowercase
        self.remove_punctuation = remove_punctuation
        self.remove_numbers = remove_numbers
        self.remove_stopwords = remove_stopwords
        self.min_word_length = min_word_length
        self.max_word_length = max_word_length
        self.lemmatize = lemmatize
        self.remove_urls = remove_urls
        self.remove_emails = remove_emails
        self.keep_sentences = keep_sentences

        if remove_stopwords:
            self.stop_words = set(stopwords.words('english'))

        if lemmatize:
            self.lemmatizer = WordNetLemmatizer()

    def clean_text(self, text):
        """Clean individual text string"""

        # Remove URLs
        if self.remove_urls:
            text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

        # Remove email addresses
        if self.remove_emails:
            text = re.sub(r'\S+@\S+', '', text)

        # Remove extra whitespace
        text = re.sub(r'\s+', ' ', text).strip()

        #Combined
         #(r'https?://\S+|www\.\S+|<.*?>|\S+@\S+\.\S+|@\w+|#\w+|[^A-Za-z0-9\s])

        return text

    def tokenize_text(self, text):
        """Tokenize text into sentences or words"""

        if self.keep_sentences:
            # Tokenize into sentences first
            sentences = sent_tokenize(text)
            processed_sentences = []

            for sentence in sentences:
                words = self.process_sentence(sentence)
                if len(words) >= 3:  # Keep sentences with at least 3 words
                    processed_sentences.append(words)

            return processed_sentences
        else:
            # Return single list of words
            return self.process_sentence(text)

    def process_sentence(self, sentence):
        """Process individual sentence"""

        # Lowercase
        if self.lowercase:
            sentence = sentence.lower()

        # Tokenize into words
        words = word_tokenize(sentence)

        processed_words = []
        for word in words:

            # Remove punctuation
            if self.remove_punctuation:
                word = word.translate(str.maketrans('', '', string.punctuation))

            # Skip if empty after punctuation removal
            if not word:
                continue

            # Remove numbers
            if self.remove_numbers and word.isdigit():
                continue

            # Check word length
            if len(word) < self.min_word_length or len(word) > self.max_word_length:
                continue

            # Remove stopwords
            if self.remove_stopwords and word in self.stop_words:
                continue

            # Lemmatize
            if self.lemmatize:
                word = self.lemmatizer.lemmatize(word)

            processed_words.append(word)

        return processed_words

    def preprocess_corpus(self, texts):
        """Preprocess entire corpus"""

        all_sentences = []

        for text in texts:
            if not isinstance(text, str):
                continue

            # Clean text
            cleaned_text = self.clean_text(text)

            # Tokenize and process
            processed = self.tokenize_text(cleaned_text)

            if self.keep_sentences:
                all_sentences.extend(processed)
            else:
                all_sentences.append(processed)

        return all_sentences

# %% [markdown]
# **Cross check the preprocessed data**

# %%
# Example usage
preprocessor = AdvancedTextPreprocessor(
    lowercase=True,
    remove_punctuation = True,
    remove_numbers=True,
    remove_stopwords=False,  # Keep stopwords for Word2Vec
    lemmatize=False,  # Usually not needed for Word2Vec
    keep_sentences=True
)

# Processing corpus
processed_sentences = preprocessor.preprocess_corpus(texts)
print(f"Processed {len(processed_sentences)} sentences")
print(f"Sample sentence: {processed_sentences[0]}")
# Out:
# Processed 2941 sentences
# Sample sentence: ['alice', 'adventures', 'in', 'wonderland']

# %%
processed_sentences[:3]
# Out:
# [['alice', 'adventures', 'in', 'wonderland'],
#  ['the', 'millennium', 'fulcrum', 'edition'],
#  ['down', 'the', 'rabbithole']]

# %% [markdown]
# This Python function, `recommend_parameters`, provides a set of **recommended parameters** for training a **Word2Vec** model. It takes four inputs: `corpus_size`, `vocab_size`, `domain_type`, and `computing_resources`. The function uses a series of conditional statements to determine optimal values for common Word2Vec parameters like:
#
# * **`vector_size`**: The dimensionality of the word vectors, which increases for larger corpora to capture more nuance.
# * **`window`**: The maximum distance between the current and predicted word, adjusted based on the `domain_type` (e.g., smaller for technical domains to focus on syntax, larger for academic domains to capture broader semantic context).
# * **`min_count`**: The minimum frequency of a word to be included in the vocabulary, scaled with the `corpus_size`.
# * **`sg`**: The training algorithm, with Skip-gram (`sg=1`) being recommended for technical and academic domains to better handle rare words, while CBOW (`sg=0`) is used for general text.
# * **`epochs`**: The number of training iterations, which is influenced by both corpus size and `computing_resources`.
# * **`hs` vs. `negative`**: The training optimization, where hierarchical softmax (`hs=1`) is recommended for very large vocabularies to improve efficiency, while negative sampling (`negative=10`) is preferred for smaller vocabularies.
#
# The final output is a dictionary containing the recommended parameter values tailored to the specific characteristics of the input data and available resources.

# %%
def recommend_parameters(corpus_size, vocab_size, domain_type, computing_resources):
    """
    Recommend Word2Vec parameters based on corpus characteristics

    Args:
        corpus_size: Number of sentences/documents
        vocab_size: Unique words in vocabulary
        domain_type: 'general', 'technical', 'social_media', 'academic'
        computing_resources: 'limited', 'moderate', 'high'
    """

    recommendations = {}

    # Vector size based on corpus and vocab size
    if corpus_size < 10000:
        recommendations['vector_size'] = 50
    elif corpus_size < 100000:
        recommendations['vector_size'] = 100
    elif corpus_size < 1000000:
        recommendations['vector_size'] = 200
    else:
        recommendations['vector_size'] = 300

    # Window size based on domain
    domain_windows = {
        'general': 5,
        'technical': 3,  # More syntactic focus
        'social_media': 4,
        'academic': 6    # More semantic focus
    }
    recommendations['window'] = domain_windows.get(domain_type, 5)

    # Min count based on corpus size
    if corpus_size < 10000:
        recommendations['min_count'] = 1
    elif corpus_size < 100000:
        recommendations['min_count'] = 2
    elif corpus_size < 1000000:
        recommendations['min_count'] = 5
    else:
        recommendations['min_count'] = 10

    # Algorithm selection
    if domain_type in ['technical', 'academic']:
        recommendations['sg'] = 1  # Skip-gram for rare technical terms
    else:
        recommendations['sg'] = 0  # CBOW for general text

    # Epochs based on corpus size and resources
    if computing_resources == 'limited':
        recommendations['epochs'] = 5
    elif corpus_size < 100000:
        recommendations['epochs'] = 15
    else:
        recommendations['epochs'] = 10

    # Hierarchical softmax vs negative sampling
    if vocab_size > 100000:
        recommendations['hs'] = 1
        recommendations['negative'] = 0
    else:
        recommendations['hs'] = 0
        recommendations['negative'] = 10

    return recommendations

# %%
corpus_size = len(processed_sentences)
print(f"Corpus Size: {corpus_size}")

# Calculate vocabulary size (unique words in vocabulary)
vocab = set(word for sentence in processed_sentences for word in sentence)
vocab_size = len(vocab)
print(f"Vocabulary Size: {vocab_size}")
# Out:
# Corpus Size: 2941
# Vocabulary Size: 2519

# %%
# For this task
params = recommend_parameters(
    corpus_size=corpus_size,
    vocab_size=vocab_size,
    domain_type='general',
    computing_resources='moderate'
)
print("Recommended parameters:", params)
# Out:
# Recommended parameters: {'vector_size': 50, 'window': 5, 'min_count': 1, 'sg': 0, 'epochs': 15, 'hs': 0, 'negative': 10}

# %% [markdown]
# ## Section 3: Traning the model
#
# Installing **Gensim** to easily implement and train powerful topic modeling and word embedding models like **Word2Vec**.

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)

# %% [markdown]
# Using Gensim's `Word2Vec` class, which handles all the complex mathematical and computational aspects of the training process. Instead of manually coding the neural network architecture, optimizations (like negative sampling and hierarchical softmax), and multithreading from scratch.
#
# The library also provides utility classes, such as `CallbackAny2Vec`, which the code uses to log training progress, making it easier to monitor your model's performance.

# %%
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec
import time
import multiprocessing

class EpochLogger(CallbackAny2Vec):
    """Callback to log information about training progress"""

    def __init__(self):
        self.epoch = 0
        self.start_time = time.time()

    def on_epoch_begin(self, model):
        print(f"Epoch #{self.epoch} start")

    def on_epoch_end(self, model):
        elapsed = time.time() - self.start_time
        print(f"Epoch #{self.epoch} end - Time elapsed: {elapsed:.2f}s")
        self.epoch += 1

def train_word2vec_model(sentences, save_path=None, **params):
    """
    Train Word2Vec model with given parameters

    Args:
        sentences: List of tokenized sentences
        save_path: Path to save the model
        **params: Word2Vec parameters
    """

    # Set default parameters
    default_params = {
        'vector_size': 100,
        'window': 5,
        'min_count': 5,
        'workers': multiprocessing.cpu_count() - 1,
        'sg': 0,  # CBOW
        'epochs': 10,
        'alpha': 0.025,
        'min_alpha': 0.0001,
        'hs': 0,
        'negative': 10
    }

    # Update with provided parameters
    default_params.update(params)

    print("Training Word2Vec model with parameters:")
    for key, value in default_params.items():
        print(f"  {key}: {value}")

    # Add callback for progress monitoring
    epoch_logger = EpochLogger()

    # Train the model
    print(f"\nTraining on {len(sentences)} sentences...")
    start_time = time.time()

    model = Word2Vec(
        sentences=sentences,
        callbacks=[epoch_logger],
        **default_params
    )

    training_time = time.time() - start_time
    print(f"\nTraining completed in {training_time:.2f} seconds")
    print(f"Vocabulary size: {len(model.wv)} words")

    # Save model if path provided
    if save_path:
        model.save(save_path)
        print(f"Model saved to {save_path}")

    return model

# %%
# Example usage
model = train_word2vec_model(
    sentences=processed_sentences,
    save_path='my_word2vec_model.model',
    vector_size=50,
    window=2,
    min_count=2,
    epochs=10000,
    compute_loss = True
)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch #7502 start
# Epoch #7502 end - Time elapsed: 410.81s
# Epoch #7503 start
# Epoch #7503 end - Time elapsed: 410.86s
# Epoch #7504 start
# Epoch #7504 end - Time elapsed: 410.91s
# Epoch #7505 start
# Epoch #7505 end - Time elapsed: 410.96s
# Epoch #7506 start
# Epoch #7506 end - Time elapsed: 411.01s
# Epoch #7507 start
# Epoch #7507 end - Time elapsed: 411.05s
# Epoch #7508 start
# Epoch #7508 end - Time elapsed: 411.10s
# Epoch #7509 start
# Epoch #7509 end - Time elapsed: 411.15s
# Epoch #7510 start
# Epoch #7510 end - Time elapsed: 411.20s
# Epoch #7511 start
# Epoch #7511 end - Time elapsed: 411.25s
# Epoch #7512 start
# Epoch #7512 end - Time elapsed: 411.29s
# Epoch #7513 start
# Epoch #7513 end - Time elapsed: 411.35s
# Epoch #7514 start
# Epoch #7514 end - Time elapsed: 411.39s
# Epoch #7515 start
# Epoch #7515 end - Time elapsed: 411.44s
# Epoch #7516 start
# Epoch #7516 end - Time elapsed: 411.49s
# Epoch #7517 start
# Epoch #7517 end - Time elapsed: 411.54s
# Epoch #7518 start
# Epoch #7518 end - Time elapsed: 411.59s
# Epoch #7519 start
# Epoch #7519 end - Time elapsed: 411.63s
# Epoch #7520 start
# Epoch #7520 end - Time elapsed: 411.68s
# Epoch #7521 start
# Epoch #7521 end - Time elapsed: 411.74s
# Epoch #7522 start
# Epoch #7522 end - Time elapsed: 411.79s
# Epoch #7523 start
# Epoch #7523 end - Time elapsed: 411.84s
# Epoch #7524 start
# Epoch #7524 end - Time elapsed: 411.89s
# Epoch #7525 start
# Epoch #7525 end - Time elapsed: 411.94s
# Epoch #7526 start
# Epoch #7526 end - Time elapsed: 411.98s
# Epoch #7527 start
# Epoch #7527 end - Time elapsed: 412.03s
# Epoch #7528 start
# Epoch #7528 end - Time elapsed: 412.08s
# Epoch #7529 start
# Epoch #7529 end - Time elapsed: 412.13s
# Epoch #7530 start
# Epoch #7530 end - Time elapsed: 412.18s
# Epoch #7531 start
# Epoch #7531 end - Time elapsed: 412.24s
# Epoch #7532 start
# Epoch #7532 end - Time elapsed: 412.32s
# Epoch #7533 start
# Epoch #7533 end - Time elapsed: 412.39s
# Epoch #7534 start
# Epoch #7534 end - Time elapsed: 412.47s
# Epoch #7535 start
# Epoch #7535 end - Time elapsed: 412.55s
# Epoch #7536 start
# Epoch #7536 end - Time elapsed: 412.61s
# Epoch #7537 start
# Epoch #7537 end - Time elapsed: 412.68s
# Epoch #7538 start
# Epoch #7538 end - Time elapsed: 412.76s
# Epoch #7539 start
# Epoch #7539 end - Time elapsed: 412.84s
# Epoch #7540 start
# Epoch #7540 end - Time elapsed: 412.91s
# Epoch #7541 start
# Epoch #7541 end - Time elapsed: 412.98s
# Epoch #7542 start
# Epoch #7542 end - Time elapsed: 413.05s
# Epoch #7543 start
# Epoch #7543 end - Time elapsed: 413.11s
# Epoch #7544 start
# Epoch #7544 end - Time elapsed: 413.19s
# Epoch #7545 start
# Epoch #7545 end - Time elapsed: 413.25s
# Epoch #7546 start
# Epoch #7546 end - Time elapsed: 413.32s
# Epoch #7547 start
# Epoch #7547 end - Time elapsed: 413.39s
# Epoch #7548 start
# Epoch #7548 end - Time elapsed: 413.47s
# Epoch #7549 start
# Epoch #7549 end - Time elapsed: 413.55s
# Epoch #7550 start
# Epoch #7550 end - Time elapsed: 413.62s
# Epoch #7551 start
# Epoch #7551 end - Time elapsed: 413.70s
# Epoch #7552 start
# Epoch #7552 end - Time elapsed: 413.77s
# Epoch #7553 start
# Epoch #7553 end - Time elapsed: 413.85s
# Epoch #7554 start
# Epoch #7554 end - Time elapsed: 413.92s
# Epoch #7555 start
# Epoch #7555 end - Time elapsed: 414.00s
# Epoch #7556 start
# Epoch #7556 end - Time elapsed: 414.07s
# Epoch #7557 start
# Epoch #7557 end - Time elapsed: 414.14s
# Epoch #7558 start
# Epoch #7558 end - Time elapsed: 414.21s
# Epoch #7559 start
# Epoch #7559 end - Time elapsed: 414.28s
# Epoch #7560 start
# Epoch #7560 end - Time elapsed: 414.35s
# Epoch #7561 start
# Epoch #7561 end - Time elapsed: 414.43s
# Epoch #7562 start
# Epoch #7562 end - Time elapsed: 414.50s
# Epoch #7563 start
# Epoch #7563 end - Time elapsed: 414.57s
# Epoch #7564 start
# Epoch #7564 end - Time elapsed: 414.66s
# Epoch #7565 start
# Epoch #7565 end - Time elapsed: 414.73s
# Epoch #7566 start
# Epoch #7566 end - Time elapsed: 414.80s
# Epoch #7567 start
# Epoch #7567 end - Time elapsed: 414.87s
# Epoch #7568 start
# Epoch #7568 end - Time elapsed: 414.94s
# Epoch #7569 start
# Epoch #7569 end - Time elapsed: 415.02s
# Epoch #7570 start
# Epoch #7570 end - Time elapsed: 415.08s
# Epoch #7571 start
# Epoch #7571 end - Time elapsed: 415.15s
# Epoch #7572 start
# Epoch #7572 end - Time elapsed: 415.21s
# Epoch #7573 start
# Epoch #7573 end - Time elapsed: 415.29s
# Epoch #7574 start
# Epoch #7574 end - Time elapsed: 415.36s
# Epoch #7575 start
# Epoch #7575 end - Time elapsed: 415.43s
# Epoch #7576 start
# Epoch #7576 end - Time elapsed: 415.50s
# Epoch #7577 start
# Epoch #7577 end - Time elapsed: 415.58s
# Epoch #7578 start
# Epoch #7578 end - Time elapsed: 415.66s
# Epoch #7579 start
# Epoch #7579 end - Time elapsed: 415.73s
# Epoch #7580 start
# Epoch #7580 end - Time elapsed: 415.80s
# Epoch #7581 start
# Epoch #7581 end - Time elapsed: 415.87s
# Epoch #7582 start
# Epoch #7582 end - Time elapsed: 415.95s
# Epoch #7583 start
# Epoch #7583 end - Time elapsed: 416.04s
# Epoch #7584 start
# Epoch #7584 end - Time elapsed: 416.11s
# Epoch #7585 start
# Epoch #7585 end - Time elapsed: 416.19s
# Epoch #7586 start
# Epoch #7586 end - Time elapsed: 416.26s
# Epoch #7587 start
# Epoch #7587 end - Time elapsed: 416.34s
# Epoch #7588 start
# Epoch #7588 end - Time elapsed: 416.41s
# Epoch #7589 start
# Epoch #7589 end - Time elapsed: 416.46s
# Epoch #7590 start
# Epoch #7590 end - Time elapsed: 416.51s
# Epoch #7591 start
# Epoch #7591 end - Time elapsed: 416.55s
# Epoch #7592 start
# Epoch #7592 end - Time elapsed: 416.60s
# Epoch #7593 start
# Epoch #7593 end - Time elapsed: 416.65s
# Epoch #7594 start
# Epoch #7594 end - Time elapsed: 416.70s
# Epoch #7595 start
# Epoch #7595 end - Time elapsed: 416.75s
# Epoch #7596 start
# Epoch #7596 end - Time elapsed: 416.80s
# Epoch #7597 start
# Epoch #7597 end - Time elapsed: 416.85s
# Epoch #7598 start
# Epoch #7598 end - Time elapsed: 416.90s
# Epoch #7599 start
# Epoch #7599 end - Time elapsed: 416.95s
# Epoch #7600 start
# Epoch #7600 end - Time elapsed: 417.00s
# Epoch #7601 start
# Epoch #7601 end - Time elapsed: 417.05s
# Epoch #7602 start
# Epoch #7602 end - Time elapsed: 417.11s
# Epoch #7603 start
# Epoch #7603 end - Time elapsed: 417.16s
# Epoch #7604 start
# Epoch #7604 end - Time elapsed: 417.20s
# Epoch #7605 start
# Epoch #7605 end - Time elapsed: 417.25s
# Epoch #7606 start
# Epoch #7606 end - Time elapsed: 417.30s
# Epoch #7607 start
# Epoch #7607 end - Time elapsed: 417.35s
# Epoch #7608 start
# Epoch #7608 end - Time elapsed: 417.40s
# Epoch #7609 start
# Epoch #7609 end - Time elapsed: 417.45s
# Epoch #7610 start
# Epoch #7610 end - Time elapsed: 417.50s
# Epoch #7611 start
# Epoch #7611 end - Time elapsed: 417.55s
# Epoch #7612 start
# Epoch #7612 end - Time elapsed: 417.60s
# Epoch #7613 start
# Epoch #7613 end - Time elapsed: 417.65s
# Epoch #7614 start
# Epoch #7614 end - Time elapsed: 417.69s
# Epoch #7615 start
# Epoch #7615 end - Time elapsed: 417.74s
# Epoch #7616 start
# Epoch #7616 end - Time elapsed: 417.79s
# Epoch #7617 start
# Epoch #7617 end - Time elapsed: 417.84s
# Epoch #7618 start
# Epoch #7618 end - Time elapsed: 417.89s
# Epoch #7619 start
# Epoch #7619 end - Time elapsed: 417.94s
# Epoch #7620 start
# Epoch #7620 end - Time elapsed: 417.99s
# Epoch #7621 start
# Epoch #7621 end - Time elapsed: 418.03s
# Epoch #7622 start
# Epoch #7622 end - Time elapsed: 418.09s
# Epoch #7623 start
# Epoch #7623 end - Time elapsed: 418.15s
# Epoch #7624 start
# Epoch #7624 end - Time elapsed: 418.19s
# Epoch #7625 start
# Epoch #7625 end - Time elapsed: 418.24s
# Epoch #7626 start
# Epoch #7626 end - Time elapsed: 418.29s
# Epoch #7627 start
# Epoch #7627 end - Time elapsed: 418.34s
# Epoch #7628 start
# Epoch #7628 end - Time elapsed: 418.39s
# Epoch #7629 start
# Epoch #7629 end - Time elapsed: 418.44s
# Epoch #7630 start
# Epoch #7630 end - Time elapsed: 418.49s
# Epoch #7631 start
# Epoch #7631 end - Time elapsed: 418.53s
# Epoch #7632 start
# Epoch #7632 end - Time elapsed: 418.59s
# Epoch #7633 start
# Epoch #7633 end - Time elapsed: 418.64s
# Epoch #7634 start
# Epoch #7634 end - Time elapsed: 418.69s
# Epoch #7635 start
# Epoch #7635 end - Time elapsed: 418.73s
# Epoch #7636 start
# Epoch #7636 end - Time elapsed: 418.78s
# Epoch #7637 start
# Epoch #7637 end - Time elapsed: 418.84s
# Epoch #7638 start
# Epoch #7638 end - Time elapsed: 418.88s
# Epoch #7639 start
# Epoch #7639 end - Time elapsed: 418.94s
# Epoch #7640 start
# Epoch #7640 end - Time elapsed: 418.99s
# Epoch #7641 start
# Epoch #7641 end - Time elapsed: 419.04s
# Epoch #7642 start
# Epoch #7642 end - Time elapsed: 419.09s
# Epoch #7643 start
# Epoch #7643 end - Time elapsed: 419.14s
# Epoch #7644 start
# Epoch #7644 end - Time elapsed: 419.20s
# Epoch #7645 start
# Epoch #7645 end - Time elapsed: 419.25s
# Epoch #7646 start
# Epoch #7646 end - Time elapsed: 419.30s
# Epoch #7647 start
# Epoch #7647 end - Time elapsed: 419.34s
# Epoch #7648 start
# Epoch #7648 end - Time elapsed: 419.39s
# Epoch #7649 start
# Epoch #7649 end - Time elapsed: 419.44s
# Epoch #7650 start
# Epoch #7650 end - Time elapsed: 419.49s
# Epoch #7651 start
# Epoch #7651 end - Time elapsed: 419.54s
# Epoch #7652 start
# Epoch #7652 end - Time elapsed: 419.59s
# Epoch #7653 start
# Epoch #7653 end - Time elapsed: 419.64s
# Epoch #7654 start
# Epoch #7654 end - Time elapsed: 419.70s
# Epoch #7655 start
# Epoch #7655 end - Time elapsed: 419.75s
# Epoch #7656 start
# Epoch #7656 end - Time elapsed: 419.79s
# Epoch #7657 start
# Epoch #7657 end - Time elapsed: 419.84s
# Epoch #7658 start
# Epoch #7658 end - Time elapsed: 419.89s
# Epoch #7659 start
# Epoch #7659 end - Time elapsed: 419.95s
# Epoch #7660 start
# Epoch #7660 end - Time elapsed: 420.00s
# Epoch #7661 start
# Epoch #7661 end - Time elapsed: 420.05s
# Epoch #7662 start
# Epoch #7662 end - Time elapsed: 420.09s
# Epoch #7663 start
# Epoch #7663 end - Time elapsed: 420.14s
# Epoch #7664 start
# Epoch #7664 end - Time elapsed: 420.21s
# Epoch #7665 start
# Epoch #7665 end - Time elapsed: 420.26s
# Epoch #7666 start
# Epoch #7666 end - Time elapsed: 420.30s
# Epoch #7667 start
# Epoch #7667 end - Time elapsed: 420.35s
# Epoch #7668 start
# Epoch #7668 end - Time elapsed: 420.40s
# Epoch #7669 start
# Epoch #7669 end - Time elapsed: 420.45s
# Epoch #7670 start
# Epoch #7670 end - Time elapsed: 420.50s
# Epoch #7671 start
# Epoch #7671 end - Time elapsed: 420.55s
# Epoch #7672 start
# Epoch #7672 end - Time elapsed: 420.60s
# Epoch #7673 start
# Epoch #7673 end - Time elapsed: 420.65s
# Epoch #7674 start
# Epoch #7674 end - Time elapsed: 420.70s
# Epoch #7675 start
# Epoch #7675 end - Time elapsed: 420.75s
# Epoch #7676 start
# Epoch #7676 end - Time elapsed: 420.80s
# Epoch #7677 start
# Epoch #7677 end - Time elapsed: 420.85s
# Epoch #7678 start
# Epoch #7678 end - Time elapsed: 420.89s
# Epoch #7679 start
# Epoch #7679 end - Time elapsed: 420.94s
# Epoch #7680 start
# Epoch #7680 end - Time elapsed: 420.99s
# Epoch #7681 start
# Epoch #7681 end - Time elapsed: 421.04s
# Epoch #7682 start
# Epoch #7682 end - Time elapsed: 421.09s
# Epoch #7683 start
# Epoch #7683 end - Time elapsed: 421.14s
# Epoch #7684 start
# Epoch #7684 end - Time elapsed: 421.19s
# Epoch #7685 start
# Epoch #7685 end - Time elapsed: 421.25s
# Epoch #7686 start
# Epoch #7686 end - Time elapsed: 421.30s
# Epoch #7687 start
# Epoch #7687 end - Time elapsed: 421.34s
# Epoch #7688 start
# Epoch #7688 end - Time elapsed: 421.39s
# Epoch #7689 start
# Epoch #7689 end - Time elapsed: 421.44s
# Epoch #7690 start
# Epoch #7690 end - Time elapsed: 421.49s
# Epoch #7691 start
# Epoch #7691 end - Time elapsed: 421.54s
# Epoch #7692 start
# Epoch #7692 end - Time elapsed: 421.59s
# Epoch #7693 start
# Epoch #7693 end - Time elapsed: 421.64s
# Epoch #7694 start
# Epoch #7694 end - Time elapsed: 421.69s
# Epoch #7695 start
# Epoch #7695 end - Time elapsed: 421.74s
# Epoch #7696 start
# Epoch #7696 end - Time elapsed: 421.79s
# Epoch #7697 start
# Epoch #7697 end - Time elapsed: 421.84s
# Epoch #7698 start
# Epoch #7698 end - Time elapsed: 421.89s
# Epoch #7699 start
# Epoch #7699 end - Time elapsed: 421.94s
# Epoch #7700 start
# Epoch #7700 end - Time elapsed: 421.99s
# Epoch #7701 start
# Epoch #7701 end - Time elapsed: 422.04s
# Epoch #7702 start
# Epoch #7702 end - Time elapsed: 422.08s
# Epoch #7703 start
# Epoch #7703 end - Time elapsed: 422.14s
# Epoch #7704 start
# Epoch #7704 end - Time elapsed: 422.19s
# Epoch #7705 start
# Epoch #7705 end - Time elapsed: 422.24s
# Epoch #7706 start
# Epoch #7706 end - Time elapsed: 422.30s
# Epoch #7707 start
# Epoch #7707 end - Time elapsed: 422.35s
# Epoch #7708 start
# Epoch #7708 end - Time elapsed: 422.39s
# Epoch #7709 start
# Epoch #7709 end - Time elapsed: 422.44s
# Epoch #7710 start
# Epoch #7710 end - Time elapsed: 422.49s
# Epoch #7711 start
# Epoch #7711 end - Time elapsed: 422.54s
# Epoch #7712 start
# Epoch #7712 end - Time elapsed: 422.60s
# Epoch #7713 start
# Epoch #7713 end - Time elapsed: 422.65s
# Epoch #7714 start
# Epoch #7714 end - Time elapsed: 422.70s
# Epoch #7715 start
# Epoch #7715 end - Time elapsed: 422.75s
# Epoch #7716 start
# Epoch #7716 end - Time elapsed: 422.79s
# Epoch #7717 start
# Epoch #7717 end - Time elapsed: 422.85s
# Epoch #7718 start
# Epoch #7718 end - Time elapsed: 422.90s
# Epoch #7719 start
# Epoch #7719 end - Time elapsed: 422.95s
# Epoch #7720 start
# Epoch #7720 end - Time elapsed: 422.99s
# Epoch #7721 start
# Epoch #7721 end - Time elapsed: 423.04s
# Epoch #7722 start
# Epoch #7722 end - Time elapsed: 423.09s
# Epoch #7723 start
# Epoch #7723 end - Time elapsed: 423.14s
# Epoch #7724 start
# Epoch #7724 end - Time elapsed: 423.19s
# Epoch #7725 start
# Epoch #7725 end - Time elapsed: 423.24s
# Epoch #7726 start
# Epoch #7726 end - Time elapsed: 423.29s
# Epoch #7727 start
# Epoch #7727 end - Time elapsed: 423.35s
# Epoch #7728 start
# Epoch #7728 end - Time elapsed: 423.40s
# Epoch #7729 start
# Epoch #7729 end - Time elapsed: 423.45s
# Epoch #7730 start
# Epoch #7730 end - Time elapsed: 423.50s
# Epoch #7731 start
# Epoch #7731 end - Time elapsed: 423.55s
# Epoch #7732 start
# Epoch #7732 end - Time elapsed: 423.60s
# Epoch #7733 start
# Epoch #7733 end - Time elapsed: 423.65s
# Epoch #7734 start
# Epoch #7734 end - Time elapsed: 423.70s
# Epoch #7735 start
# Epoch #7735 end - Time elapsed: 423.75s
# Epoch #7736 start
# Epoch #7736 end - Time elapsed: 423.80s
# Epoch #7737 start
# Epoch #7737 end - Time elapsed: 423.86s
# Epoch #7738 start
# Epoch #7738 end - Time elapsed: 423.91s
# Epoch #7739 start
# Epoch #7739 end - Time elapsed: 423.95s
# Epoch #7740 start
# Epoch #7740 end - Time elapsed: 424.00s
# Epoch #7741 start
# Epoch #7741 end - Time elapsed: 424.05s
# Epoch #7742 start
# Epoch #7742 end - Time elapsed: 424.11s
# Epoch #7743 start
# Epoch #7743 end - Time elapsed: 424.15s
# Epoch #7744 start
# Epoch #7744 end - Time elapsed: 424.20s
# Epoch #7745 start
# Epoch #7745 end - Time elapsed: 424.25s
# Epoch #7746 start
# Epoch #7746 end - Time elapsed: 424.29s
# Epoch #7747 start
# Epoch #7747 end - Time elapsed: 424.36s
# Epoch #7748 start
# Epoch #7748 end - Time elapsed: 424.41s
# Epoch #7749 start
# Epoch #7749 end - Time elapsed: 424.46s
# Epoch #7750 start
# Epoch #7750 end - Time elapsed: 424.51s
# Epoch #7751 start
# Epoch #7751 end - Time elapsed: 424.55s
# Epoch #7752 start
# Epoch #7752 end - Time elapsed: 424.60s
# Epoch #7753 start
# Epoch #7753 end - Time elapsed: 424.65s
# Epoch #7754 start
# Epoch #7754 end - Time elapsed: 424.70s
# Epoch #7755 start
# Epoch #7755 end - Time elapsed: 424.75s
# Epoch #7756 start
# Epoch #7756 end - Time elapsed: 424.80s
# Epoch #7757 start
# Epoch #7757 end - Time elapsed: 424.85s
# Epoch #7758 start
# Epoch #7758 end - Time elapsed: 424.90s
# Epoch #7759 start
# Epoch #7759 end - Time elapsed: 424.95s
# Epoch #7760 start
# Epoch #7760 end - Time elapsed: 424.99s
# Epoch #7761 start
# Epoch #7761 end - Time elapsed: 425.04s
# Epoch #7762 start
# Epoch #7762 end - Time elapsed: 425.09s
# Epoch #7763 start
# Epoch #7763 end - Time elapsed: 425.14s
# Epoch #7764 start
# Epoch #7764 end - Time elapsed: 425.19s
# Epoch #7765 start
# Epoch #7765 end - Time elapsed: 425.23s
# Epoch #7766 start
# Epoch #7766 end - Time elapsed: 425.28s
# Epoch #7767 start
# Epoch #7767 end - Time elapsed: 425.34s
# Epoch #7768 start
# Epoch #7768 end - Time elapsed: 425.39s
# Epoch #7769 start
# Epoch #7769 end - Time elapsed: 425.45s
# Epoch #7770 start
# Epoch #7770 end - Time elapsed: 425.50s
# Epoch #7771 start
# Epoch #7771 end - Time elapsed: 425.54s
# Epoch #7772 start
# Epoch #7772 end - Time elapsed: 425.60s
# Epoch #7773 start
# Epoch #7773 end - Time elapsed: 425.64s
# Epoch #7774 start
# Epoch #7774 end - Time elapsed: 425.69s
# Epoch #7775 start
# Epoch #7775 end - Time elapsed: 425.74s
# Epoch #7776 start
# Epoch #7776 end - Time elapsed: 425.79s
# Epoch #7777 start
# Epoch #7777 end - Time elapsed: 425.84s
# Epoch #7778 start
# Epoch #7778 end - Time elapsed: 425.89s
# Epoch #7779 start
# Epoch #7779 end - Time elapsed: 425.94s
# Epoch #7780 start
# Epoch #7780 end - Time elapsed: 425.98s
# Epoch #7781 start
# Epoch #7781 end - Time elapsed: 426.03s
# Epoch #7782 start
# Epoch #7782 end - Time elapsed: 426.08s
# Epoch #7783 start
# Epoch #7783 end - Time elapsed: 426.13s
# Epoch #7784 start
# Epoch #7784 end - Time elapsed: 426.18s
# Epoch #7785 start
# Epoch #7785 end - Time elapsed: 426.22s
# Epoch #7786 start
# Epoch #7786 end - Time elapsed: 426.27s
# Epoch #7787 start
# Epoch #7787 end - Time elapsed: 426.32s
# Epoch #7788 start
# Epoch #7788 end - Time elapsed: 426.37s
# Epoch #7789 start
# Epoch #7789 end - Time elapsed: 426.44s
# Epoch #7790 start
# Epoch #7790 end - Time elapsed: 426.52s
# Epoch #7791 start
# Epoch #7791 end - Time elapsed: 426.59s
# Epoch #7792 start
# Epoch #7792 end - Time elapsed: 426.66s
# Epoch #7793 start
# Epoch #7793 end - Time elapsed: 426.73s
# Epoch #7794 start
# Epoch #7794 end - Time elapsed: 426.80s
# Epoch #7795 start
# Epoch #7795 end - Time elapsed: 426.87s
# Epoch #7796 start
# Epoch #7796 end - Time elapsed: 426.95s
# Epoch #7797 start
# Epoch #7797 end - Time elapsed: 427.02s
# Epoch #7798 start
# Epoch #7798 end - Time elapsed: 427.09s
# Epoch #7799 start
# Epoch #7799 end - Time elapsed: 427.16s
# Epoch #7800 start
# Epoch #7800 end - Time elapsed: 427.23s
# Epoch #7801 start
# Epoch #7801 end - Time elapsed: 427.30s
# Epoch #7802 start
# Epoch #7802 end - Time elapsed: 427.37s
# Epoch #7803 start
# Epoch #7803 end - Time elapsed: 427.44s
# Epoch #7804 start
# Epoch #7804 end - Time elapsed: 427.52s
# Epoch #7805 start
# Epoch #7805 end - Time elapsed: 427.61s
# Epoch #7806 start
# Epoch #7806 end - Time elapsed: 427.68s
# Epoch #7807 start
# Epoch #7807 end - Time elapsed: 427.75s
# Epoch #7808 start
# Epoch #7808 end - Time elapsed: 427.83s
# Epoch #7809 start
# Epoch #7809 end - Time elapsed: 427.91s
# Epoch #7810 start
# Epoch #7810 end - Time elapsed: 427.98s
# Epoch #7811 start
# Epoch #7811 end - Time elapsed: 428.05s
# Epoch #7812 start
# Epoch #7812 end - Time elapsed: 428.12s
# Epoch #7813 start
# Epoch #7813 end - Time elapsed: 428.19s
# Epoch #7814 start
# Epoch #7814 end - Time elapsed: 428.27s
# Epoch #7815 start
# Epoch #7815 end - Time elapsed: 428.34s
# Epoch #7816 start
# Epoch #7816 end - Time elapsed: 428.40s
# Epoch #7817 start
# Epoch #7817 end - Time elapsed: 428.48s
# Epoch #7818 start
# Epoch #7818 end - Time elapsed: 428.55s
# Epoch #7819 start
# Epoch #7819 end - Time elapsed: 428.65s
# Epoch #7820 start
# Epoch #7820 end - Time elapsed: 428.72s
# Epoch #7821 start
# Epoch #7821 end - Time elapsed: 428.79s
# Epoch #7822 start
# Epoch #7822 end - Time elapsed: 428.86s
# Epoch #7823 start
# Epoch #7823 end - Time elapsed: 428.93s
# Epoch #7824 start
# Epoch #7824 end - Time elapsed: 429.01s
# Epoch #7825 start
# Epoch #7825 end - Time elapsed: 429.07s
# Epoch #7826 start
# Epoch #7826 end - Time elapsed: 429.14s
# Epoch #7827 start
# Epoch #7827 end - Time elapsed: 429.21s
# Epoch #7828 start
# Epoch #7828 end - Time elapsed: 429.27s
# Epoch #7829 start
# Epoch #7829 end - Time elapsed: 429.34s
# Epoch #7830 start
# Epoch #7830 end - Time elapsed: 429.41s
# Epoch #7831 start
# Epoch #7831 end - Time elapsed: 429.48s
# Epoch #7832 start
# Epoch #7832 end - Time elapsed: 429.54s
# Epoch #7833 start
# Epoch #7833 end - Time elapsed: 429.62s
# Epoch #7834 start
# Epoch #7834 end - Time elapsed: 429.72s
# Epoch #7835 start
# Epoch #7835 end - Time elapsed: 429.79s
# Epoch #7836 start
# Epoch #7836 end - Time elapsed: 429.87s
# Epoch #7837 start
# Epoch #7837 end - Time elapsed: 429.94s
# Epoch #7838 start
# Epoch #7838 end - Time elapsed: 430.01s
# Epoch #7839 start
# Epoch #7839 end - Time elapsed: 430.09s
# Epoch #7840 start
# Epoch #7840 end - Time elapsed: 430.16s
# Epoch #7841 start
# Epoch #7841 end - Time elapsed: 430.23s
# Epoch #7842 start
# Epoch #7842 end - Time elapsed: 430.30s
# Epoch #7843 start
# Epoch #7843 end - Time elapsed: 430.37s
# Epoch #7844 start
# Epoch #7844 end - Time elapsed: 430.44s
# Epoch #7845 start
# Epoch #7845 end - Time elapsed: 430.52s
# Epoch #7846 start
# Epoch #7846 end - Time elapsed: 430.60s
# Epoch #7847 start
# Epoch #7847 end - Time elapsed: 430.64s
# Epoch #7848 start
# Epoch #7848 end - Time elapsed: 430.69s
# Epoch #7849 start
# Epoch #7849 end - Time elapsed: 430.76s
# Epoch #7850 start
# Epoch #7850 end - Time elapsed: 430.81s
# Epoch #7851 start
# Epoch #7851 end - Time elapsed: 430.86s
# Epoch #7852 start
# Epoch #7852 end - Time elapsed: 430.91s
# Epoch #7853 start
# Epoch #7853 end - Time elapsed: 430.95s
# Epoch #7854 start
# Epoch #7854 end - Time elapsed: 431.00s
# Epoch #7855 start
# Epoch #7855 end - Time elapsed: 431.05s
# Epoch #7856 start
# Epoch #7856 end - Time elapsed: 431.10s
# Epoch #7857 start
# Epoch #7857 end - Time elapsed: 431.15s
# Epoch #7858 start
# Epoch #7858 end - Time elapsed: 431.19s
# Epoch #7859 start
# Epoch #7859 end - Time elapsed: 431.24s
# Epoch #7860 start
# Epoch #7860 end - Time elapsed: 431.29s
# Epoch #7861 start
# Epoch #7861 end - Time elapsed: 431.34s
# Epoch #7862 start
# Epoch #7862 end - Time elapsed: 431.39s
# Epoch #7863 start
# Epoch #7863 end - Time elapsed: 431.44s
# Epoch #7864 start
# Epoch #7864 end - Time elapsed: 431.49s
# Epoch #7865 start
# Epoch #7865 end - Time elapsed: 431.54s
# Epoch #7866 start
# Epoch #7866 end - Time elapsed: 431.59s
# Epoch #7867 start
# Epoch #7867 end - Time elapsed: 431.64s
# Epoch #7868 start
# Epoch #7868 end - Time elapsed: 431.68s
# Epoch #7869 start
# Epoch #7869 end - Time elapsed: 431.74s
# Epoch #7870 start
# Epoch #7870 end - Time elapsed: 431.80s
# Epoch #7871 start
# Epoch #7871 end - Time elapsed: 431.85s
# Epoch #7872 start
# Epoch #7872 end - Time elapsed: 431.89s
# Epoch #7873 start
# Epoch #7873 end - Time elapsed: 431.94s
# Epoch #7874 start
# Epoch #7874 end - Time elapsed: 431.99s
# Epoch #7875 start
# Epoch #7875 end - Time elapsed: 432.04s
# Epoch #7876 start
# Epoch #7876 end - Time elapsed: 432.09s
# Epoch #7877 start
# Epoch #7877 end - Time elapsed: 432.13s
# Epoch #7878 start
# Epoch #7878 end - Time elapsed: 432.18s
# Epoch #7879 start
# Epoch #7879 end - Time elapsed: 432.23s
# Epoch #7880 start
# Epoch #7880 end - Time elapsed: 432.28s
# Epoch #7881 start
# Epoch #7881 end - Time elapsed: 432.33s
# Epoch #7882 start
# Epoch #7882 end - Time elapsed: 432.37s
# Epoch #7883 start
# Epoch #7883 end - Time elapsed: 432.42s
# Epoch #7884 start
# Epoch #7884 end - Time elapsed: 432.47s
# Epoch #7885 start
# Epoch #7885 end - Time elapsed: 432.52s
# Epoch #7886 start
# Epoch #7886 end - Time elapsed: 432.57s
# Epoch #7887 start
# Epoch #7887 end - Time elapsed: 432.62s
# Epoch #7888 start
# Epoch #7888 end - Time elapsed: 432.67s
# Epoch #7889 start
# Epoch #7889 end - Time elapsed: 432.72s
# Epoch #7890 start
# Epoch #7890 end - Time elapsed: 432.76s
# Epoch #7891 start
# Epoch #7891 end - Time elapsed: 432.83s
# Epoch #7892 start
# Epoch #7892 end - Time elapsed: 432.88s
# Epoch #7893 start
# Epoch #7893 end - Time elapsed: 432.93s
# Epoch #7894 start
# Epoch #7894 end - Time elapsed: 432.97s
# Epoch #7895 start
# Epoch #7895 end - Time elapsed: 433.02s
# Epoch #7896 start
# Epoch #7896 end - Time elapsed: 433.07s
# Epoch #7897 start
# Epoch #7897 end - Time elapsed: 433.12s
# Epoch #7898 start
# Epoch #7898 end - Time elapsed: 433.17s
# Epoch #7899 start
# Epoch #7899 end - Time elapsed: 433.21s
# Epoch #7900 start
# Epoch #7900 end - Time elapsed: 433.26s
# Epoch #7901 start
# Epoch #7901 end - Time elapsed: 433.31s
# Epoch #7902 start
# Epoch #7902 end - Time elapsed: 433.36s
# Epoch #7903 start
# Epoch #7903 end - Time elapsed: 433.41s
# Epoch #7904 start
# Epoch #7904 end - Time elapsed: 433.45s
# Epoch #7905 start
# Epoch #7905 end - Time elapsed: 433.50s
# Epoch #7906 start
# Epoch #7906 end - Time elapsed: 433.55s
# Epoch #7907 start
# Epoch #7907 end - Time elapsed: 433.60s
# Epoch #7908 start
# Epoch #7908 end - Time elapsed: 433.65s
# Epoch #7909 start
# Epoch #7909 end - Time elapsed: 433.69s
# Epoch #7910 start
# Epoch #7910 end - Time elapsed: 433.74s
# Epoch #7911 start
# Epoch #7911 end - Time elapsed: 433.79s
# Epoch #7912 start
# Epoch #7912 end - Time elapsed: 433.86s
# Epoch #7913 start
# Epoch #7913 end - Time elapsed: 433.91s
# Epoch #7914 start
# Epoch #7914 end - Time elapsed: 433.96s
# Epoch #7915 start
# Epoch #7915 end - Time elapsed: 434.00s
# Epoch #7916 start
# Epoch #7916 end - Time elapsed: 434.05s
# Epoch #7917 start
# Epoch #7917 end - Time elapsed: 434.10s
# Epoch #7918 start
# Epoch #7918 end - Time elapsed: 434.15s
# Epoch #7919 start
# Epoch #7919 end - Time elapsed: 434.20s
# Epoch #7920 start
# Epoch #7920 end - Time elapsed: 434.25s
# Epoch #7921 start
# Epoch #7921 end - Time elapsed: 434.29s
# Epoch #7922 start
# Epoch #7922 end - Time elapsed: 434.34s
# Epoch #7923 start
# Epoch #7923 end - Time elapsed: 434.39s
# Epoch #7924 start
# Epoch #7924 end - Time elapsed: 434.44s
# Epoch #7925 start
# Epoch #7925 end - Time elapsed: 434.49s
# Epoch #7926 start
# Epoch #7926 end - Time elapsed: 434.54s
# Epoch #7927 start
# Epoch #7927 end - Time elapsed: 434.59s
# Epoch #7928 start
# Epoch #7928 end - Time elapsed: 434.64s
# Epoch #7929 start
# Epoch #7929 end - Time elapsed: 434.69s
# Epoch #7930 start
# Epoch #7930 end - Time elapsed: 434.74s
# Epoch #7931 start
# Epoch #7931 end - Time elapsed: 434.78s
# Epoch #7932 start
# Epoch #7932 end - Time elapsed: 434.84s
# Epoch #7933 start
# Epoch #7933 end - Time elapsed: 434.90s
# Epoch #7934 start
# Epoch #7934 end - Time elapsed: 434.95s
# Epoch #7935 start
# Epoch #7935 end - Time elapsed: 435.00s
# Epoch #7936 start
# Epoch #7936 end - Time elapsed: 435.04s
# Epoch #7937 start
# Epoch #7937 end - Time elapsed: 435.09s
# Epoch #7938 start
# Epoch #7938 end - Time elapsed: 435.14s
# Epoch #7939 start
# Epoch #7939 end - Time elapsed: 435.19s
# Epoch #7940 start
# Epoch #7940 end - Time elapsed: 435.24s
# Epoch #7941 start
# Epoch #7941 end - Time elapsed: 435.29s
# Epoch #7942 start
# Epoch #7942 end - Time elapsed: 435.34s
# Epoch #7943 start
# Epoch #7943 end - Time elapsed: 435.39s
# Epoch #7944 start
# Epoch #7944 end - Time elapsed: 435.44s
# Epoch #7945 start
# Epoch #7945 end - Time elapsed: 435.49s
# Epoch #7946 start
# Epoch #7946 end - Time elapsed: 435.54s
# Epoch #7947 start
# Epoch #7947 end - Time elapsed: 435.59s
# Epoch #7948 start
# Epoch #7948 end - Time elapsed: 435.64s
# Epoch #7949 start
# Epoch #7949 end - Time elapsed: 435.69s
# Epoch #7950 start
# Epoch #7950 end - Time elapsed: 435.74s
# Epoch #7951 start
# Epoch #7951 end - Time elapsed: 435.79s
# Epoch #7952 start
# Epoch #7952 end - Time elapsed: 435.84s
# Epoch #7953 start
# Epoch #7953 end - Time elapsed: 435.90s
# Epoch #7954 start
# Epoch #7954 end - Time elapsed: 435.98s
# Epoch #7955 start
# Epoch #7955 end - Time elapsed: 436.03s
# Epoch #7956 start
# Epoch #7956 end - Time elapsed: 436.08s
# Epoch #7957 start
# Epoch #7957 end - Time elapsed: 436.12s
# Epoch #7958 start
# Epoch #7958 end - Time elapsed: 436.17s
# Epoch #7959 start
# Epoch #7959 end - Time elapsed: 436.22s
# Epoch #7960 start
# Epoch #7960 end - Time elapsed: 436.28s
# Epoch #7961 start
# Epoch #7961 end - Time elapsed: 436.32s
# Epoch #7962 start
# Epoch #7962 end - Time elapsed: 436.37s
# Epoch #7963 start
# Epoch #7963 end - Time elapsed: 436.42s
# Epoch #7964 start
# Epoch #7964 end - Time elapsed: 436.48s
# Epoch #7965 start
# Epoch #7965 end - Time elapsed: 436.53s
# Epoch #7966 start
# Epoch #7966 end - Time elapsed: 436.58s
# Epoch #7967 start
# Epoch #7967 end - Time elapsed: 436.64s
# Epoch #7968 start
# Epoch #7968 end - Time elapsed: 436.69s
# Epoch #7969 start
# Epoch #7969 end - Time elapsed: 436.74s
# Epoch #7970 start
# Epoch #7970 end - Time elapsed: 436.79s
# Epoch #7971 start
# Epoch #7971 end - Time elapsed: 436.84s
# Epoch #7972 start
# Epoch #7972 end - Time elapsed: 436.88s
# Epoch #7973 start
# Epoch #7973 end - Time elapsed: 436.93s
# Epoch #7974 start
# Epoch #7974 end - Time elapsed: 437.00s
# Epoch #7975 start
# Epoch #7975 end - Time elapsed: 437.05s
# Epoch #7976 start
# Epoch #7976 end - Time elapsed: 437.10s
# Epoch #7977 start
# Epoch #7977 end - Time elapsed: 437.14s
# Epoch #7978 start
# Epoch #7978 end - Time elapsed: 437.19s
# Epoch #7979 start
# Epoch #7979 end - Time elapsed: 437.25s
# Epoch #7980 start
# Epoch #7980 end - Time elapsed: 437.29s
# Epoch #7981 start
# Epoch #7981 end - Time elapsed: 437.34s
# Epoch #7982 start
# Epoch #7982 end - Time elapsed: 437.39s
# Epoch #7983 start
# Epoch #7983 end - Time elapsed: 437.44s
# Epoch #7984 start
# Epoch #7984 end - Time elapsed: 437.49s
# Epoch #7985 start
# Epoch #7985 end - Time elapsed: 437.54s
# Epoch #7986 start
# Epoch #7986 end - Time elapsed: 437.59s
# Epoch #7987 start
# Epoch #7987 end - Time elapsed: 437.64s
# Epoch #7988 start
# Epoch #7988 end - Time elapsed: 437.69s
# Epoch #7989 start
# Epoch #7989 end - Time elapsed: 437.74s
# Epoch #7990 start
# Epoch #7990 end - Time elapsed: 437.79s
# Epoch #7991 start
# Epoch #7991 end - Time elapsed: 437.84s
# Epoch #7992 start
# Epoch #7992 end - Time elapsed: 437.88s
# Epoch #7993 start
# Epoch #7993 end - Time elapsed: 437.93s
# Epoch #7994 start
# Epoch #7994 end - Time elapsed: 437.98s
# Epoch #7995 start
# Epoch #7995 end - Time elapsed: 438.05s
# Epoch #7996 start
# Epoch #7996 end - Time elapsed: 438.09s
# Epoch #7997 start
# Epoch #7997 end - Time elapsed: 438.14s
# Epoch #7998 start
# Epoch #7998 end - Time elapsed: 438.19s
# Epoch #7999 start
# Epoch #7999 end - Time elapsed: 438.24s
# Epoch #8000 start
# Epoch #8000 end - Time elapsed: 438.29s
# Epoch #8001 start
# Epoch #8001 end - Time elapsed: 438.34s
# Epoch #8002 start
# Epoch #8002 end - Time elapsed: 438.39s
# Epoch #8003 start
# Epoch #8003 end - Time elapsed: 438.44s
# Epoch #8004 start
# Epoch #8004 end - Time elapsed: 438.49s
# Epoch #8005 start
# Epoch #8005 end - Time elapsed: 438.54s
# Epoch #8006 start
# Epoch #8006 end - Time elapsed: 438.59s
# Epoch #8007 start
# Epoch #8007 end - Time elapsed: 438.64s
# Epoch #8008 start
# Epoch #8008 end - Time elapsed: 438.69s
# Epoch #8009 start
# Epoch #8009 end - Time elapsed: 438.74s
# Epoch #8010 start
# Epoch #8010 end - Time elapsed: 438.79s
# Epoch #8011 start
# Epoch #8011 end - Time elapsed: 438.84s
# Epoch #8012 start
# Epoch #8012 end - Time elapsed: 438.89s
# Epoch #8013 start
# Epoch #8013 end - Time elapsed: 438.94s
# Epoch #8014 start
# Epoch #8014 end - Time elapsed: 438.99s
# Epoch #8015 start
# Epoch #8015 end - Time elapsed: 439.04s
# Epoch #8016 start
# Epoch #8016 end - Time elapsed: 439.09s
# Epoch #8017 start
# Epoch #8017 end - Time elapsed: 439.14s
# Epoch #8018 start
# Epoch #8018 end - Time elapsed: 439.19s
# Epoch #8019 start
# Epoch #8019 end - Time elapsed: 439.24s
# Epoch #8020 start
# Epoch #8020 end - Time elapsed: 439.29s
# Epoch #8021 start
# Epoch #8021 end - Time elapsed: 439.33s
# Epoch #8022 start
# Epoch #8022 end - Time elapsed: 439.39s
# Epoch #8023 start
# Epoch #8023 end - Time elapsed: 439.44s
# Epoch #8024 start
# Epoch #8024 end - Time elapsed: 439.48s
# Epoch #8025 start
# Epoch #8025 end - Time elapsed: 439.53s
# Epoch #8026 start
# Epoch #8026 end - Time elapsed: 439.58s
# Epoch #8027 start
# Epoch #8027 end - Time elapsed: 439.63s
# Epoch #8028 start
# Epoch #8028 end - Time elapsed: 439.68s
# Epoch #8029 start
# Epoch #8029 end - Time elapsed: 439.73s
# Epoch #8030 start
# Epoch #8030 end - Time elapsed: 439.78s
# Epoch #8031 start
# Epoch #8031 end - Time elapsed: 439.83s
# Epoch #8032 start
# Epoch #8032 end - Time elapsed: 439.88s
# Epoch #8033 start
# Epoch #8033 end - Time elapsed: 439.93s
# Epoch #8034 start
# Epoch #8034 end - Time elapsed: 439.98s
# Epoch #8035 start
# Epoch #8035 end - Time elapsed: 440.03s
# Epoch #8036 start
# Epoch #8036 end - Time elapsed: 440.08s
# Epoch #8037 start
# Epoch #8037 end - Time elapsed: 440.14s
# Epoch #8038 start
# Epoch #8038 end - Time elapsed: 440.19s
# Epoch #8039 start
# Epoch #8039 end - Time elapsed: 440.24s
# Epoch #8040 start
# Epoch #8040 end - Time elapsed: 440.28s
# Epoch #8041 start
# Epoch #8041 end - Time elapsed: 440.33s
# Epoch #8042 start
# Epoch #8042 end - Time elapsed: 440.39s
# Epoch #8043 start
# Epoch #8043 end - Time elapsed: 440.43s
# Epoch #8044 start
# Epoch #8044 end - Time elapsed: 440.48s
# Epoch #8045 start
# Epoch #8045 end - Time elapsed: 440.53s
# Epoch #8046 start
# Epoch #8046 end - Time elapsed: 440.58s
# Epoch #8047 start
# Epoch #8047 end - Time elapsed: 440.65s
# Epoch #8048 start
# Epoch #8048 end - Time elapsed: 440.72s
# Epoch #8049 start
# Epoch #8049 end - Time elapsed: 440.80s
# Epoch #8050 start
# Epoch #8050 end - Time elapsed: 440.88s
# Epoch #8051 start
# Epoch #8051 end - Time elapsed: 440.95s
# Epoch #8052 start
# Epoch #8052 end - Time elapsed: 441.02s
# Epoch #8053 start
# Epoch #8053 end - Time elapsed: 441.09s
# Epoch #8054 start
# Epoch #8054 end - Time elapsed: 441.17s
# Epoch #8055 start
# Epoch #8055 end - Time elapsed: 441.24s
# Epoch #8056 start
# Epoch #8056 end - Time elapsed: 441.31s
# Epoch #8057 start
# Epoch #8057 end - Time elapsed: 441.39s
# Epoch #8058 start
# Epoch #8058 end - Time elapsed: 441.45s
# Epoch #8059 start
# Epoch #8059 end - Time elapsed: 441.53s
# Epoch #8060 start
# Epoch #8060 end - Time elapsed: 441.60s
# Epoch #8061 start
# Epoch #8061 end - Time elapsed: 441.67s
# Epoch #8062 start
# Epoch #8062 end - Time elapsed: 441.76s
# Epoch #8063 start
# Epoch #8063 end - Time elapsed: 441.83s
# Epoch #8064 start
# Epoch #8064 end - Time elapsed: 441.90s
# Epoch #8065 start
# Epoch #8065 end - Time elapsed: 441.98s
# Epoch #8066 start
# Epoch #8066 end - Time elapsed: 442.05s
# Epoch #8067 start
# Epoch #8067 end - Time elapsed: 442.12s
# Epoch #8068 start
# Epoch #8068 end - Time elapsed: 442.20s
# Epoch #8069 start
# Epoch #8069 end - Time elapsed: 442.28s
# Epoch #8070 start
# Epoch #8070 end - Time elapsed: 442.36s
# Epoch #8071 start
# Epoch #8071 end - Time elapsed: 442.44s
# Epoch #8072 start
# Epoch #8072 end - Time elapsed: 442.51s
# Epoch #8073 start
# Epoch #8073 end - Time elapsed: 442.58s
# Epoch #8074 start
# Epoch #8074 end - Time elapsed: 442.66s
# Epoch #8075 start
# Epoch #8075 end - Time elapsed: 442.73s
# Epoch #8076 start
# Epoch #8076 end - Time elapsed: 442.80s
# Epoch #8077 start
# Epoch #8077 end - Time elapsed: 442.87s
# Epoch #8078 start
# Epoch #8078 end - Time elapsed: 442.94s
# Epoch #8079 start
# Epoch #8079 end - Time elapsed: 443.02s
# Epoch #8080 start
# Epoch #8080 end - Time elapsed: 443.09s
# Epoch #8081 start
# Epoch #8081 end - Time elapsed: 443.16s
# Epoch #8082 start
# Epoch #8082 end - Time elapsed: 443.23s
# Epoch #8083 start
# Epoch #8083 end - Time elapsed: 443.31s
# Epoch #8084 start
# Epoch #8084 end - Time elapsed: 443.39s
# Epoch #8085 start
# Epoch #8085 end - Time elapsed: 443.45s
# Epoch #8086 start
# Epoch #8086 end - Time elapsed: 443.52s
# Epoch #8087 start
# Epoch #8087 end - Time elapsed: 443.60s
# Epoch #8088 start
# Epoch #8088 end - Time elapsed: 443.67s
# Epoch #8089 start
# Epoch #8089 end - Time elapsed: 443.73s
# Epoch #8090 start
# Epoch #8090 end - Time elapsed: 443.80s
# Epoch #8091 start
# Epoch #8091 end - Time elapsed: 443.87s
# Epoch #8092 start
# Epoch #8092 end - Time elapsed: 443.95s
# Epoch #8093 start
# Epoch #8093 end - Time elapsed: 444.03s
# Epoch #8094 start
# Epoch #8094 end - Time elapsed: 444.10s
# Epoch #8095 start
# Epoch #8095 end - Time elapsed: 444.18s
# Epoch #8096 start
# Epoch #8096 end - Time elapsed: 444.25s
# Epoch #8097 start
# Epoch #8097 end - Time elapsed: 444.32s
# Epoch #8098 start
# Epoch #8098 end - Time elapsed: 444.40s
# Epoch #8099 start
# Epoch #8099 end - Time elapsed: 444.48s
# Epoch #8100 start
# Epoch #8100 end - Time elapsed: 444.55s
# Epoch #8101 start
# Epoch #8101 end - Time elapsed: 444.63s
# Epoch #8102 start
# Epoch #8102 end - Time elapsed: 444.70s
# Epoch #8103 start
# Epoch #8103 end - Time elapsed: 444.77s
# Epoch #8104 start
# Epoch #8104 end - Time elapsed: 444.84s
# Epoch #8105 start
# Epoch #8105 end - Time elapsed: 444.89s
# Epoch #8106 start
# Epoch #8106 end - Time elapsed: 444.94s
# Epoch #8107 start
# Epoch #8107 end - Time elapsed: 444.99s
# Epoch #8108 start
# Epoch #8108 end - Time elapsed: 445.03s
# Epoch #8109 start
# Epoch #8109 end - Time elapsed: 445.09s
# Epoch #8110 start
# Epoch #8110 end - Time elapsed: 445.13s
# Epoch #8111 start
# Epoch #8111 end - Time elapsed: 445.18s
# Epoch #8112 start
# Epoch #8112 end - Time elapsed: 445.23s
# Epoch #8113 start
# Epoch #8113 end - Time elapsed: 445.28s
# Epoch #8114 start
# Epoch #8114 end - Time elapsed: 445.33s
# Epoch #8115 start
# Epoch #8115 end - Time elapsed: 445.38s
# Epoch #8116 start
# Epoch #8116 end - Time elapsed: 445.44s
# Epoch #8117 start
# Epoch #8117 end - Time elapsed: 445.49s
# Epoch #8118 start
# Epoch #8118 end - Time elapsed: 445.54s
# Epoch #8119 start
# Epoch #8119 end - Time elapsed: 445.59s
# Epoch #8120 start
# Epoch #8120 end - Time elapsed: 445.64s
# Epoch #8121 start
# Epoch #8121 end - Time elapsed: 445.69s
# Epoch #8122 start
# Epoch #8122 end - Time elapsed: 445.74s
# Epoch #8123 start
# Epoch #8123 end - Time elapsed: 445.79s
# Epoch #8124 start
# Epoch #8124 end - Time elapsed: 445.84s
# Epoch #8125 start
# Epoch #8125 end - Time elapsed: 445.88s
# Epoch #8126 start
# Epoch #8126 end - Time elapsed: 445.93s
# Epoch #8127 start
# Epoch #8127 end - Time elapsed: 445.98s
# Epoch #8128 start
# Epoch #8128 end - Time elapsed: 446.03s
# Epoch #8129 start
# Epoch #8129 end - Time elapsed: 446.08s
# Epoch #8130 start
# Epoch #8130 end - Time elapsed: 446.13s
# Epoch #8131 start
# Epoch #8131 end - Time elapsed: 446.17s
# Epoch #8132 start
# Epoch #8132 end - Time elapsed: 446.22s
# Epoch #8133 start
# Epoch #8133 end - Time elapsed: 446.27s
# Epoch #8134 start
# Epoch #8134 end - Time elapsed: 446.32s
# Epoch #8135 start
# Epoch #8135 end - Time elapsed: 446.37s
# Epoch #8136 start
# Epoch #8136 end - Time elapsed: 446.42s
# Epoch #8137 start
# Epoch #8137 end - Time elapsed: 446.49s
# Epoch #8138 start
# Epoch #8138 end - Time elapsed: 446.54s
# Epoch #8139 start
# Epoch #8139 end - Time elapsed: 446.59s
# Epoch #8140 start
# Epoch #8140 end - Time elapsed: 446.64s
# Epoch #8141 start
# Epoch #8141 end - Time elapsed: 446.69s
# Epoch #8142 start
# Epoch #8142 end - Time elapsed: 446.74s
# Epoch #8143 start
# Epoch #8143 end - Time elapsed: 446.79s
# Epoch #8144 start
# Epoch #8144 end - Time elapsed: 446.84s
# Epoch #8145 start
# Epoch #8145 end - Time elapsed: 446.88s
# Epoch #8146 start
# Epoch #8146 end - Time elapsed: 446.93s
# Epoch #8147 start
# Epoch #8147 end - Time elapsed: 446.98s
# Epoch #8148 start
# Epoch #8148 end - Time elapsed: 447.03s
# Epoch #8149 start
# Epoch #8149 end - Time elapsed: 447.08s
# Epoch #8150 start
# Epoch #8150 end - Time elapsed: 447.13s
# Epoch #8151 start
# Epoch #8151 end - Time elapsed: 447.18s
# Epoch #8152 start
# Epoch #8152 end - Time elapsed: 447.23s
# Epoch #8153 start
# Epoch #8153 end - Time elapsed: 447.28s
# Epoch #8154 start
# Epoch #8154 end - Time elapsed: 447.33s
# Epoch #8155 start
# Epoch #8155 end - Time elapsed: 447.37s
# Epoch #8156 start
# Epoch #8156 end - Time elapsed: 447.42s
# Epoch #8157 start
# Epoch #8157 end - Time elapsed: 447.47s
# Epoch #8158 start
# Epoch #8158 end - Time elapsed: 447.53s
# Epoch #8159 start
# Epoch #8159 end - Time elapsed: 447.59s
# Epoch #8160 start
# Epoch #8160 end - Time elapsed: 447.64s
# Epoch #8161 start
# Epoch #8161 end - Time elapsed: 447.69s
# Epoch #8162 start
# Epoch #8162 end - Time elapsed: 447.73s
# Epoch #8163 start
# Epoch #8163 end - Time elapsed: 447.78s
# Epoch #8164 start
# Epoch #8164 end - Time elapsed: 447.83s
# Epoch #8165 start
# Epoch #8165 end - Time elapsed: 447.88s
# Epoch #8166 start
# Epoch #8166 end - Time elapsed: 447.93s
# Epoch #8167 start
# Epoch #8167 end - Time elapsed: 447.98s
# Epoch #8168 start
# Epoch #8168 end - Time elapsed: 448.02s
# Epoch #8169 start
# Epoch #8169 end - Time elapsed: 448.07s
# Epoch #8170 start
# Epoch #8170 end - Time elapsed: 448.12s
# Epoch #8171 start
# Epoch #8171 end - Time elapsed: 448.17s
# Epoch #8172 start
# Epoch #8172 end - Time elapsed: 448.22s
# Epoch #8173 start
# Epoch #8173 end - Time elapsed: 448.27s
# Epoch #8174 start
# Epoch #8174 end - Time elapsed: 448.31s
# Epoch #8175 start
# Epoch #8175 end - Time elapsed: 448.36s
# Epoch #8176 start
# Epoch #8176 end - Time elapsed: 448.41s
# Epoch #8177 start
# Epoch #8177 end - Time elapsed: 448.46s
# Epoch #8178 start
# Epoch #8178 end - Time elapsed: 448.51s
# Epoch #8179 start
# Epoch #8179 end - Time elapsed: 448.57s
# Epoch #8180 start
# Epoch #8180 end - Time elapsed: 448.63s
# Epoch #8181 start
# Epoch #8181 end - Time elapsed: 448.68s
# Epoch #8182 start
# Epoch #8182 end - Time elapsed: 448.73s
# Epoch #8183 start
# Epoch #8183 end - Time elapsed: 448.77s
# Epoch #8184 start
# Epoch #8184 end - Time elapsed: 448.82s
# Epoch #8185 start
# Epoch #8185 end - Time elapsed: 448.87s
# Epoch #8186 start
# Epoch #8186 end - Time elapsed: 448.92s
# Epoch #8187 start
# Epoch #8187 end - Time elapsed: 448.97s
# Epoch #8188 start
# Epoch #8188 end - Time elapsed: 449.02s
# Epoch #8189 start
# Epoch #8189 end - Time elapsed: 449.07s
# Epoch #8190 start
# Epoch #8190 end - Time elapsed: 449.12s
# Epoch #8191 start
# Epoch #8191 end - Time elapsed: 449.17s
# Epoch #8192 start
# Epoch #8192 end - Time elapsed: 449.22s
# Epoch #8193 start
# Epoch #8193 end - Time elapsed: 449.26s
# Epoch #8194 start
# Epoch #8194 end - Time elapsed: 449.31s
# Epoch #8195 start
# Epoch #8195 end - Time elapsed: 449.37s
# Epoch #8196 start
# Epoch #8196 end - Time elapsed: 449.42s
# Epoch #8197 start
# Epoch #8197 end - Time elapsed: 449.47s
# Epoch #8198 start
# Epoch #8198 end - Time elapsed: 449.51s
# Epoch #8199 start
# Epoch #8199 end - Time elapsed: 449.56s
# Epoch #8200 start
# Epoch #8200 end - Time elapsed: 449.63s
# Epoch #8201 start
# Epoch #8201 end - Time elapsed: 449.68s
# Epoch #8202 start
# Epoch #8202 end - Time elapsed: 449.73s
# Epoch #8203 start
# Epoch #8203 end - Time elapsed: 449.78s
# Epoch #8204 start
# Epoch #8204 end - Time elapsed: 449.82s
# Epoch #8205 start
# Epoch #8205 end - Time elapsed: 449.88s
# Epoch #8206 start
# Epoch #8206 end - Time elapsed: 449.93s
# Epoch #8207 start
# Epoch #8207 end - Time elapsed: 449.98s
# Epoch #8208 start
# Epoch #8208 end - Time elapsed: 450.02s
# Epoch #8209 start
# Epoch #8209 end - Time elapsed: 450.07s
# Epoch #8210 start
# Epoch #8210 end - Time elapsed: 450.12s
# Epoch #8211 start
# Epoch #8211 end - Time elapsed: 450.17s
# Epoch #8212 start
# Epoch #8212 end - Time elapsed: 450.22s
# Epoch #8213 start
# Epoch #8213 end - Time elapsed: 450.26s
# Epoch #8214 start
# Epoch #8214 end - Time elapsed: 450.31s
# Epoch #8215 start
# Epoch #8215 end - Time elapsed: 450.36s
# Epoch #8216 start
# Epoch #8216 end - Time elapsed: 450.41s
# Epoch #8217 start
# Epoch #8217 end - Time elapsed: 450.46s
# Epoch #8218 start
# Epoch #8218 end - Time elapsed: 450.51s
# Epoch #8219 start
# Epoch #8219 end - Time elapsed: 450.56s
# Epoch #8220 start
# Epoch #8220 end - Time elapsed: 450.62s
# Epoch #8221 start
# Epoch #8221 end - Time elapsed: 450.68s
# Epoch #8222 start
# Epoch #8222 end - Time elapsed: 450.73s
# Epoch #8223 start
# Epoch #8223 end - Time elapsed: 450.78s
# Epoch #8224 start
# Epoch #8224 end - Time elapsed: 450.83s
# Epoch #8225 start
# Epoch #8225 end - Time elapsed: 450.88s
# Epoch #8226 start
# Epoch #8226 end - Time elapsed: 450.92s
# Epoch #8227 start
# Epoch #8227 end - Time elapsed: 450.97s
# Epoch #8228 start
# Epoch #8228 end - Time elapsed: 451.02s
# Epoch #8229 start
# Epoch #8229 end - Time elapsed: 451.07s
# Epoch #8230 start
# Epoch #8230 end - Time elapsed: 451.12s
# Epoch #8231 start
# Epoch #8231 end - Time elapsed: 451.17s
# Epoch #8232 start
# Epoch #8232 end - Time elapsed: 451.21s
# Epoch #8233 start
# Epoch #8233 end - Time elapsed: 451.26s
# Epoch #8234 start
# Epoch #8234 end - Time elapsed: 451.31s
# Epoch #8235 start
# Epoch #8235 end - Time elapsed: 451.36s
# Epoch #8236 start
# Epoch #8236 end - Time elapsed: 451.41s
# Epoch #8237 start
# Epoch #8237 end - Time elapsed: 451.46s
# Epoch #8238 start
# Epoch #8238 end - Time elapsed: 451.50s
# Epoch #8239 start
# Epoch #8239 end - Time elapsed: 451.56s
# Epoch #8240 start
# Epoch #8240 end - Time elapsed: 451.61s
# Epoch #8241 start
# Epoch #8241 end - Time elapsed: 451.66s
# Epoch #8242 start
# Epoch #8242 end - Time elapsed: 451.72s
# Epoch #8243 start
# Epoch #8243 end - Time elapsed: 451.77s
# Epoch #8244 start
# Epoch #8244 end - Time elapsed: 451.82s
# Epoch #8245 start
# Epoch #8245 end - Time elapsed: 451.87s
# Epoch #8246 start
# Epoch #8246 end - Time elapsed: 451.91s
# Epoch #8247 start
# Epoch #8247 end - Time elapsed: 451.96s
# Epoch #8248 start
# Epoch #8248 end - Time elapsed: 452.02s
# Epoch #8249 start
# Epoch #8249 end - Time elapsed: 452.07s
# Epoch #8250 start
# Epoch #8250 end - Time elapsed: 452.12s
# Epoch #8251 start
# Epoch #8251 end - Time elapsed: 452.16s
# Epoch #8252 start
# Epoch #8252 end - Time elapsed: 452.21s
# Epoch #8253 start
# Epoch #8253 end - Time elapsed: 452.26s
# Epoch #8254 start
# Epoch #8254 end - Time elapsed: 452.31s
# Epoch #8255 start
# Epoch #8255 end - Time elapsed: 452.36s
# Epoch #8256 start
# Epoch #8256 end - Time elapsed: 452.41s
# Epoch #8257 start
# Epoch #8257 end - Time elapsed: 452.46s
# Epoch #8258 start
# Epoch #8258 end - Time elapsed: 452.51s
# Epoch #8259 start
# Epoch #8259 end - Time elapsed: 452.56s
# Epoch #8260 start
# Epoch #8260 end - Time elapsed: 452.61s
# Epoch #8261 start
# Epoch #8261 end - Time elapsed: 452.66s
# Epoch #8262 start
# Epoch #8262 end - Time elapsed: 452.72s
# Epoch #8263 start
# Epoch #8263 end - Time elapsed: 452.78s
# Epoch #8264 start
# Epoch #8264 end - Time elapsed: 452.82s
# Epoch #8265 start
# Epoch #8265 end - Time elapsed: 452.87s
# Epoch #8266 start
# Epoch #8266 end - Time elapsed: 452.92s
# Epoch #8267 start
# Epoch #8267 end - Time elapsed: 452.97s
# Epoch #8268 start
# Epoch #8268 end - Time elapsed: 453.02s
# Epoch #8269 start
# Epoch #8269 end - Time elapsed: 453.07s
# Epoch #8270 start
# Epoch #8270 end - Time elapsed: 453.12s
# Epoch #8271 start
# Epoch #8271 end - Time elapsed: 453.17s
# Epoch #8272 start
# Epoch #8272 end - Time elapsed: 453.22s
# Epoch #8273 start
# Epoch #8273 end - Time elapsed: 453.26s
# Epoch #8274 start
# Epoch #8274 end - Time elapsed: 453.31s
# Epoch #8275 start
# Epoch #8275 end - Time elapsed: 453.36s
# Epoch #8276 start
# Epoch #8276 end - Time elapsed: 453.41s
# Epoch #8277 start
# Epoch #8277 end - Time elapsed: 453.46s
# Epoch #8278 start
# Epoch #8278 end - Time elapsed: 453.52s
# Epoch #8279 start
# Epoch #8279 end - Time elapsed: 453.59s
# Epoch #8280 start
# Epoch #8280 end - Time elapsed: 453.66s
# Epoch #8281 start
# Epoch #8281 end - Time elapsed: 453.72s
# Epoch #8282 start
# Epoch #8282 end - Time elapsed: 453.79s
# Epoch #8283 start
# Epoch #8283 end - Time elapsed: 453.85s
# Epoch #8284 start
# Epoch #8284 end - Time elapsed: 453.91s
# Epoch #8285 start
# Epoch #8285 end - Time elapsed: 453.96s
# Epoch #8286 start
# Epoch #8286 end - Time elapsed: 454.02s
# Epoch #8287 start
# Epoch #8287 end - Time elapsed: 454.07s
# Epoch #8288 start
# Epoch #8288 end - Time elapsed: 454.13s
# Epoch #8289 start
# Epoch #8289 end - Time elapsed: 454.19s
# Epoch #8290 start
# Epoch #8290 end - Time elapsed: 454.24s
# Epoch #8291 start
# Epoch #8291 end - Time elapsed: 454.30s
# Epoch #8292 start
# Epoch #8292 end - Time elapsed: 454.36s
# Epoch #8293 start
# Epoch #8293 end - Time elapsed: 454.41s
# Epoch #8294 start
# Epoch #8294 end - Time elapsed: 454.47s
# Epoch #8295 start
# Epoch #8295 end - Time elapsed: 454.52s
# Epoch #8296 start
# Epoch #8296 end - Time elapsed: 454.58s
# Epoch #8297 start
# Epoch #8297 end - Time elapsed: 454.65s
# Epoch #8298 start
# Epoch #8298 end - Time elapsed: 454.71s
# Epoch #8299 start
# Epoch #8299 end - Time elapsed: 454.76s
# Epoch #8300 start
# Epoch #8300 end - Time elapsed: 454.85s
# Epoch #8301 start
# Epoch #8301 end - Time elapsed: 454.95s
# Epoch #8302 start
# Epoch #8302 end - Time elapsed: 455.04s
# Epoch #8303 start
# Epoch #8303 end - Time elapsed: 455.14s
# Epoch #8304 start
# Epoch #8304 end - Time elapsed: 455.23s
# Epoch #8305 start
# Epoch #8305 end - Time elapsed: 455.34s
# Epoch #8306 start
# Epoch #8306 end - Time elapsed: 455.43s
# Epoch #8307 start
# Epoch #8307 end - Time elapsed: 455.53s
# Epoch #8308 start
# Epoch #8308 end - Time elapsed: 455.60s
# Epoch #8309 start
# Epoch #8309 end - Time elapsed: 455.69s
# Epoch #8310 start
# Epoch #8310 end - Time elapsed: 455.79s
# Epoch #8311 start
# Epoch #8311 end - Time elapsed: 455.86s
# Epoch #8312 start
# Epoch #8312 end - Time elapsed: 455.95s
# Epoch #8313 start
# Epoch #8313 end - Time elapsed: 456.07s
# Epoch #8314 start
# Epoch #8314 end - Time elapsed: 456.14s
# Epoch #8315 start
# Epoch #8315 end - Time elapsed: 456.24s
# Epoch #8316 start
# Epoch #8316 end - Time elapsed: 456.31s
# Epoch #8317 start
# Epoch #8317 end - Time elapsed: 456.38s
# Epoch #8318 start
# Epoch #8318 end - Time elapsed: 456.46s
# Epoch #8319 start
# Epoch #8319 end - Time elapsed: 456.56s
# Epoch #8320 start
# Epoch #8320 end - Time elapsed: 456.67s
# Epoch #8321 start
# Epoch #8321 end - Time elapsed: 456.77s
# Epoch #8322 start
# Epoch #8322 end - Time elapsed: 456.89s
# Epoch #8323 start
# Epoch #8323 end - Time elapsed: 457.00s
# Epoch #8324 start
# Epoch #8324 end - Time elapsed: 457.14s
# Epoch #8325 start
# Epoch #8325 end - Time elapsed: 457.24s
# Epoch #8326 start
# Epoch #8326 end - Time elapsed: 457.35s
# Epoch #8327 start
# Epoch #8327 end - Time elapsed: 457.43s
# Epoch #8328 start
# ...
# Epoch #9726 start
# Epoch #9726 end - Time elapsed: 538.46s
# Epoch #9727 start
# Epoch #9727 end - Time elapsed: 538.51s
# Epoch #9728 start
# Epoch #9728 end - Time elapsed: 538.56s
# Epoch #9729 start
# Epoch #9729 end - Time elapsed: 538.61s
# Epoch #9730 start
# Epoch #9730 end - Time elapsed: 538.66s
# Epoch #9731 start
# Epoch #9731 end - Time elapsed: 538.71s
# Epoch #9732 start
# Epoch #9732 end - Time elapsed: 538.76s
# Epoch #9733 start
# Epoch #9733 end - Time elapsed: 538.81s
# Epoch #9734 start
# Epoch #9734 end - Time elapsed: 538.87s
# Epoch #9735 start
# Epoch #9735 end - Time elapsed: 538.92s
# Epoch #9736 start
# Epoch #9736 end - Time elapsed: 538.97s
# Epoch #9737 start
# Epoch #9737 end - Time elapsed: 539.02s
# Epoch #9738 start
# Epoch #9738 end - Time elapsed: 539.07s
# Epoch #9739 start
# Epoch #9739 end - Time elapsed: 539.13s
# Epoch #9740 start
# Epoch #9740 end - Time elapsed: 539.18s
# Epoch #9741 start
# Epoch #9741 end - Time elapsed: 539.22s
# Epoch #9742 start
# Epoch #9742 end - Time elapsed: 539.27s
# Epoch #9743 start
# Epoch #9743 end - Time elapsed: 539.32s
# Epoch #9744 start
# Epoch #9744 end - Time elapsed: 539.37s
# Epoch #9745 start
# Epoch #9745 end - Time elapsed: 539.42s
# Epoch #9746 start
# Epoch #9746 end - Time elapsed: 539.48s
# Epoch #9747 start
# Epoch #9747 end - Time elapsed: 539.54s
# Epoch #9748 start
# Epoch #9748 end - Time elapsed: 539.59s
# Epoch #9749 start
# Epoch #9749 end - Time elapsed: 539.64s
# Epoch #9750 start
# Epoch #9750 end - Time elapsed: 539.69s
# Epoch #9751 start
# Epoch #9751 end - Time elapsed: 539.74s
# Epoch #9752 start
# Epoch #9752 end - Time elapsed: 539.80s
# Epoch #9753 start
# Epoch #9753 end - Time elapsed: 539.85s
# Epoch #9754 start
# Epoch #9754 end - Time elapsed: 539.90s
# Epoch #9755 start
# Epoch #9755 end - Time elapsed: 539.94s
# Epoch #9756 start
# Epoch #9756 end - Time elapsed: 539.99s
# Epoch #9757 start
# Epoch #9757 end - Time elapsed: 540.05s
# Epoch #9758 start
# Epoch #9758 end - Time elapsed: 540.10s
# Epoch #9759 start
# Epoch #9759 end - Time elapsed: 540.15s
# Epoch #9760 start
# Epoch #9760 end - Time elapsed: 540.19s
# Epoch #9761 start
# Epoch #9761 end - Time elapsed: 540.24s
# Epoch #9762 start
# Epoch #9762 end - Time elapsed: 540.30s
# Epoch #9763 start
# Epoch #9763 end - Time elapsed: 540.35s
# Epoch #9764 start
# Epoch #9764 end - Time elapsed: 540.40s
# Epoch #9765 start
# Epoch #9765 end - Time elapsed: 540.45s
# Epoch #9766 start
# Epoch #9766 end - Time elapsed: 540.50s
# Epoch #9767 start
# Epoch #9767 end - Time elapsed: 540.57s
# Epoch #9768 start
# Epoch #9768 end - Time elapsed: 540.62s
# Epoch #9769 start
# Epoch #9769 end - Time elapsed: 540.67s
# Epoch #9770 start
# Epoch #9770 end - Time elapsed: 540.72s
# Epoch #9771 start
# Epoch #9771 end - Time elapsed: 540.77s
# Epoch #9772 start
# Epoch #9772 end - Time elapsed: 540.82s
# Epoch #9773 start
# Epoch #9773 end - Time elapsed: 540.87s
# Epoch #9774 start
# Epoch #9774 end - Time elapsed: 540.92s
# Epoch #9775 start
# Epoch #9775 end - Time elapsed: 540.97s
# Epoch #9776 start
# Epoch #9776 end - Time elapsed: 541.02s
# Epoch #9777 start
# Epoch #9777 end - Time elapsed: 541.07s
# Epoch #9778 start
# Epoch #9778 end - Time elapsed: 541.12s
# Epoch #9779 start
# Epoch #9779 end - Time elapsed: 541.17s
# Epoch #9780 start
# Epoch #9780 end - Time elapsed: 541.22s
# Epoch #9781 start
# Epoch #9781 end - Time elapsed: 541.27s
# Epoch #9782 start
# Epoch #9782 end - Time elapsed: 541.32s
# Epoch #9783 start
# Epoch #9783 end - Time elapsed: 541.37s
# Epoch #9784 start
# Epoch #9784 end - Time elapsed: 541.42s
# Epoch #9785 start
# Epoch #9785 end - Time elapsed: 541.47s
# Epoch #9786 start
# Epoch #9786 end - Time elapsed: 541.52s
# Epoch #9787 start
# Epoch #9787 end - Time elapsed: 541.58s
# Epoch #9788 start
# Epoch #9788 end - Time elapsed: 541.64s
# Epoch #9789 start
# Epoch #9789 end - Time elapsed: 541.69s
# Epoch #9790 start
# Epoch #9790 end - Time elapsed: 541.73s
# Epoch #9791 start
# Epoch #9791 end - Time elapsed: 541.78s
# Epoch #9792 start
# Epoch #9792 end - Time elapsed: 541.84s
# Epoch #9793 start
# Epoch #9793 end - Time elapsed: 541.88s
# Epoch #9794 start
# Epoch #9794 end - Time elapsed: 541.93s
# Epoch #9795 start
# Epoch #9795 end - Time elapsed: 541.98s
# Epoch #9796 start
# Epoch #9796 end - Time elapsed: 542.04s
# Epoch #9797 start
# Epoch #9797 end - Time elapsed: 542.09s
# Epoch #9798 start
# Epoch #9798 end - Time elapsed: 542.14s
# Epoch #9799 start
# Epoch #9799 end - Time elapsed: 542.19s
# Epoch #9800 start
# Epoch #9800 end - Time elapsed: 542.24s
# Epoch #9801 start
# Epoch #9801 end - Time elapsed: 542.29s
# Epoch #9802 start
# Epoch #9802 end - Time elapsed: 542.34s
# Epoch #9803 start
# Epoch #9803 end - Time elapsed: 542.39s
# Epoch #9804 start
# Epoch #9804 end - Time elapsed: 542.44s
# Epoch #9805 start
# Epoch #9805 end - Time elapsed: 542.48s
# Epoch #9806 start
# Epoch #9806 end - Time elapsed: 542.54s
# Epoch #9807 start
# Epoch #9807 end - Time elapsed: 542.59s
# Epoch #9808 start
# Epoch #9808 end - Time elapsed: 542.66s
# Epoch #9809 start
# Epoch #9809 end - Time elapsed: 542.70s
# Epoch #9810 start
# Epoch #9810 end - Time elapsed: 542.76s
# Epoch #9811 start
# Epoch #9811 end - Time elapsed: 542.81s
# Epoch #9812 start
# Epoch #9812 end - Time elapsed: 542.87s
# Epoch #9813 start
# Epoch #9813 end - Time elapsed: 542.95s
# Epoch #9814 start
# Epoch #9814 end - Time elapsed: 543.02s
# Epoch #9815 start
# Epoch #9815 end - Time elapsed: 543.10s
# Epoch #9816 start
# Epoch #9816 end - Time elapsed: 543.17s
# Epoch #9817 start
# Epoch #9817 end - Time elapsed: 543.25s
# Epoch #9818 start
# Epoch #9818 end - Time elapsed: 543.32s
# Epoch #9819 start
# Epoch #9819 end - Time elapsed: 543.40s
# Epoch #9820 start
# Epoch #9820 end - Time elapsed: 543.47s
# Epoch #9821 start
# Epoch #9821 end - Time elapsed: 543.55s
# Epoch #9822 start
# Epoch #9822 end - Time elapsed: 543.62s
# Epoch #9823 start
# Epoch #9823 end - Time elapsed: 543.71s
# Epoch #9824 start
# Epoch #9824 end - Time elapsed: 543.79s
# Epoch #9825 start
# Epoch #9825 end - Time elapsed: 543.86s
# Epoch #9826 start
# Epoch #9826 end - Time elapsed: 543.97s
# Epoch #9827 start
# Epoch #9827 end - Time elapsed: 544.03s
# Epoch #9828 start
# Epoch #9828 end - Time elapsed: 544.11s
# Epoch #9829 start
# Epoch #9829 end - Time elapsed: 544.19s
# Epoch #9830 start
# Epoch #9830 end - Time elapsed: 544.26s
# Epoch #9831 start
# Epoch #9831 end - Time elapsed: 544.34s
# Epoch #9832 start
# Epoch #9832 end - Time elapsed: 544.41s
# Epoch #9833 start
# Epoch #9833 end - Time elapsed: 544.49s
# Epoch #9834 start
# Epoch #9834 end - Time elapsed: 544.56s
# Epoch #9835 start
# Epoch #9835 end - Time elapsed: 544.64s
# Epoch #9836 start
# Epoch #9836 end - Time elapsed: 544.71s
# Epoch #9837 start
# Epoch #9837 end - Time elapsed: 544.78s
# Epoch #9838 start
# Epoch #9838 end - Time elapsed: 544.87s
# Epoch #9839 start
# Epoch #9839 end - Time elapsed: 544.94s
# Epoch #9840 start
# Epoch #9840 end - Time elapsed: 545.02s
# Epoch #9841 start
# Epoch #9841 end - Time elapsed: 545.09s
# Epoch #9842 start
# Epoch #9842 end - Time elapsed: 545.17s
# Epoch #9843 start
# Epoch #9843 end - Time elapsed: 545.24s
# Epoch #9844 start
# Epoch #9844 end - Time elapsed: 545.32s
# Epoch #9845 start
# Epoch #9845 end - Time elapsed: 545.39s
# Epoch #9846 start
# Epoch #9846 end - Time elapsed: 545.47s
# Epoch #9847 start
# Epoch #9847 end - Time elapsed: 545.54s
# Epoch #9848 start
# Epoch #9848 end - Time elapsed: 545.61s
# Epoch #9849 start
# Epoch #9849 end - Time elapsed: 545.69s
# Epoch #9850 start
# Epoch #9850 end - Time elapsed: 545.76s
# Epoch #9851 start
# Epoch #9851 end - Time elapsed: 545.83s
# Epoch #9852 start
# Epoch #9852 end - Time elapsed: 545.92s
# Epoch #9853 start
# Epoch #9853 end - Time elapsed: 545.99s
# Epoch #9854 start
# Epoch #9854 end - Time elapsed: 546.06s
# Epoch #9855 start
# Epoch #9855 end - Time elapsed: 546.14s
# Epoch #9856 start
# Epoch #9856 end - Time elapsed: 546.23s
# Epoch #9857 start
# Epoch #9857 end - Time elapsed: 546.30s
# Epoch #9858 start
# Epoch #9858 end - Time elapsed: 546.37s
# Epoch #9859 start
# Epoch #9859 end - Time elapsed: 546.46s
# Epoch #9860 start
# Epoch #9860 end - Time elapsed: 546.54s
# Epoch #9861 start
# Epoch #9861 end - Time elapsed: 546.62s
# Epoch #9862 start
# Epoch #9862 end - Time elapsed: 546.69s
# Epoch #9863 start
# Epoch #9863 end - Time elapsed: 546.76s
# Epoch #9864 start
# Epoch #9864 end - Time elapsed: 546.84s
# Epoch #9865 start
# Epoch #9865 end - Time elapsed: 546.92s
# Epoch #9866 start
# Epoch #9866 end - Time elapsed: 547.01s
# Epoch #9867 start
# Epoch #9867 end - Time elapsed: 547.06s
# Epoch #9868 start
# Epoch #9868 end - Time elapsed: 547.11s
# Epoch #9869 start
# Epoch #9869 end - Time elapsed: 547.16s
# Epoch #9870 start
# Epoch #9870 end - Time elapsed: 547.21s
# Epoch #9871 start
# Epoch #9871 end - Time elapsed: 547.26s
# Epoch #9872 start
# Epoch #9872 end - Time elapsed: 547.31s
# Epoch #9873 start
# Epoch #9873 end - Time elapsed: 547.36s
# Epoch #9874 start
# Epoch #9874 end - Time elapsed: 547.41s
# Epoch #9875 start
# Epoch #9875 end - Time elapsed: 547.46s
# Epoch #9876 start
# Epoch #9876 end - Time elapsed: 547.51s
# Epoch #9877 start
# Epoch #9877 end - Time elapsed: 547.56s
# Epoch #9878 start
# Epoch #9878 end - Time elapsed: 547.62s
# Epoch #9879 start
# Epoch #9879 end - Time elapsed: 547.67s
# Epoch #9880 start
# Epoch #9880 end - Time elapsed: 547.72s
# Epoch #9881 start
# Epoch #9881 end - Time elapsed: 547.77s
# Epoch #9882 start
# Epoch #9882 end - Time elapsed: 547.83s
# Epoch #9883 start
# Epoch #9883 end - Time elapsed: 547.88s
# Epoch #9884 start
# Epoch #9884 end - Time elapsed: 547.93s
# Epoch #9885 start
# Epoch #9885 end - Time elapsed: 547.98s
# Epoch #9886 start
# Epoch #9886 end - Time elapsed: 548.05s
# Epoch #9887 start
# Epoch #9887 end - Time elapsed: 548.10s
# Epoch #9888 start
# Epoch #9888 end - Time elapsed: 548.15s
# Epoch #9889 start
# Epoch #9889 end - Time elapsed: 548.20s
# Epoch #9890 start
# Epoch #9890 end - Time elapsed: 548.25s
# Epoch #9891 start
# Epoch #9891 end - Time elapsed: 548.30s
# Epoch #9892 start
# Epoch #9892 end - Time elapsed: 548.35s
# Epoch #9893 start
# Epoch #9893 end - Time elapsed: 548.40s
# Epoch #9894 start
# Epoch #9894 end - Time elapsed: 548.45s
# Epoch #9895 start
# Epoch #9895 end - Time elapsed: 548.50s
# Epoch #9896 start
# Epoch #9896 end - Time elapsed: 548.56s
# Epoch #9897 start
# Epoch #9897 end - Time elapsed: 548.61s
# Epoch #9898 start
# Epoch #9898 end - Time elapsed: 548.65s
# Epoch #9899 start
# Epoch #9899 end - Time elapsed: 548.70s
# Epoch #9900 start
# Epoch #9900 end - Time elapsed: 548.76s
# Epoch #9901 start
# Epoch #9901 end - Time elapsed: 548.81s
# Epoch #9902 start
# Epoch #9902 end - Time elapsed: 548.86s
# Epoch #9903 start
# Epoch #9903 end - Time elapsed: 548.91s
# Epoch #9904 start
# Epoch #9904 end - Time elapsed: 548.96s
# Epoch #9905 start
# Epoch #9905 end - Time elapsed: 549.01s
# Epoch #9906 start
# Epoch #9906 end - Time elapsed: 549.08s
# Epoch #9907 start
# Epoch #9907 end - Time elapsed: 549.13s
# Epoch #9908 start
# Epoch #9908 end - Time elapsed: 549.18s
# Epoch #9909 start
# Epoch #9909 end - Time elapsed: 549.23s
# Epoch #9910 start
# Epoch #9910 end - Time elapsed: 549.28s
# Epoch #9911 start
# Epoch #9911 end - Time elapsed: 549.33s
# Epoch #9912 start
# Epoch #9912 end - Time elapsed: 549.38s
# Epoch #9913 start
# Epoch #9913 end - Time elapsed: 549.43s
# Epoch #9914 start
# Epoch #9914 end - Time elapsed: 549.48s
# Epoch #9915 start
# Epoch #9915 end - Time elapsed: 549.53s
# Epoch #9916 start
# Epoch #9916 end - Time elapsed: 549.58s
# Epoch #9917 start
# Epoch #9917 end - Time elapsed: 549.63s
# Epoch #9918 start
# Epoch #9918 end - Time elapsed: 549.68s
# Epoch #9919 start
# Epoch #9919 end - Time elapsed: 549.73s
# Epoch #9920 start
# Epoch #9920 end - Time elapsed: 549.78s
# Epoch #9921 start
# Epoch #9921 end - Time elapsed: 549.83s
# Epoch #9922 start
# Epoch #9922 end - Time elapsed: 549.88s
# Epoch #9923 start
# Epoch #9923 end - Time elapsed: 549.94s
# Epoch #9924 start
# Epoch #9924 end - Time elapsed: 549.99s
# Epoch #9925 start
# Epoch #9925 end - Time elapsed: 550.04s
# Epoch #9926 start
# Epoch #9926 end - Time elapsed: 550.10s
# Epoch #9927 start
# Epoch #9927 end - Time elapsed: 550.15s
# Epoch #9928 start
# Epoch #9928 end - Time elapsed: 550.20s
# Epoch #9929 start
# Epoch #9929 end - Time elapsed: 550.25s
# Epoch #9930 start
# Epoch #9930 end - Time elapsed: 550.30s
# Epoch #9931 start
# Epoch #9931 end - Time elapsed: 550.35s
# Epoch #9932 start
# Epoch #9932 end - Time elapsed: 550.40s
# Epoch #9933 start
# Epoch #9933 end - Time elapsed: 550.46s
# Epoch #9934 start
# Epoch #9934 end - Time elapsed: 550.51s
# Epoch #9935 start
# Epoch #9935 end - Time elapsed: 550.56s
# Epoch #9936 start
# Epoch #9936 end - Time elapsed: 550.61s
# Epoch #9937 start
# Epoch #9937 end - Time elapsed: 550.66s
# Epoch #9938 start
# Epoch #9938 end - Time elapsed: 550.72s
# Epoch #9939 start
# Epoch #9939 end - Time elapsed: 550.77s
# Epoch #9940 start
# Epoch #9940 end - Time elapsed: 550.82s
# Epoch #9941 start
# Epoch #9941 end - Time elapsed: 550.86s
# Epoch #9942 start
# Epoch #9942 end - Time elapsed: 550.91s
# Epoch #9943 start
# Epoch #9943 end - Time elapsed: 550.97s
# Epoch #9944 start
# Epoch #9944 end - Time elapsed: 551.02s
# Epoch #9945 start
# Epoch #9945 end - Time elapsed: 551.07s
# Epoch #9946 start
# Epoch #9946 end - Time elapsed: 551.12s
# Epoch #9947 start
# Epoch #9947 end - Time elapsed: 551.19s
# Epoch #9948 start
# Epoch #9948 end - Time elapsed: 551.23s
# Epoch #9949 start
# Epoch #9949 end - Time elapsed: 551.28s
# Epoch #9950 start
# Epoch #9950 end - Time elapsed: 551.33s
# Epoch #9951 start
# Epoch #9951 end - Time elapsed: 551.38s
# Epoch #9952 start
# Epoch #9952 end - Time elapsed: 551.44s
# Epoch #9953 start
# Epoch #9953 end - Time elapsed: 551.49s
# Epoch #9954 start
# Epoch #9954 end - Time elapsed: 551.54s
# Epoch #9955 start
# Epoch #9955 end - Time elapsed: 551.59s
# Epoch #9956 start
# Epoch #9956 end - Time elapsed: 551.64s
# Epoch #9957 start
# Epoch #9957 end - Time elapsed: 551.69s
# Epoch #9958 start
# Epoch #9958 end - Time elapsed: 551.74s
# Epoch #9959 start
# Epoch #9959 end - Time elapsed: 551.79s
# Epoch #9960 start
# Epoch #9960 end - Time elapsed: 551.84s
# Epoch #9961 start
# Epoch #9961 end - Time elapsed: 551.90s
# Epoch #9962 start
# Epoch #9962 end - Time elapsed: 551.95s
# Epoch #9963 start
# Epoch #9963 end - Time elapsed: 552.00s
# Epoch #9964 start
# Epoch #9964 end - Time elapsed: 552.05s
# Epoch #9965 start
# Epoch #9965 end - Time elapsed: 552.10s
# Epoch #9966 start
# Epoch #9966 end - Time elapsed: 552.15s
# Epoch #9967 start
# Epoch #9967 end - Time elapsed: 552.22s
# Epoch #9968 start
# Epoch #9968 end - Time elapsed: 552.27s
# Epoch #9969 start
# Epoch #9969 end - Time elapsed: 552.32s
# Epoch #9970 start
# Epoch #9970 end - Time elapsed: 552.37s
# Epoch #9971 start
# Epoch #9971 end - Time elapsed: 552.42s
# Epoch #9972 start
# Epoch #9972 end - Time elapsed: 552.48s
# Epoch #9973 start
# Epoch #9973 end - Time elapsed: 552.52s
# Epoch #9974 start
# Epoch #9974 end - Time elapsed: 552.58s
# Epoch #9975 start
# Epoch #9975 end - Time elapsed: 552.63s
# Epoch #9976 start
# Epoch #9976 end - Time elapsed: 552.68s
# Epoch #9977 start
# Epoch #9977 end - Time elapsed: 552.73s
# Epoch #9978 start
# Epoch #9978 end - Time elapsed: 552.78s
# Epoch #9979 start
# Epoch #9979 end - Time elapsed: 552.83s
# Epoch #9980 start
# Epoch #9980 end - Time elapsed: 552.88s
# Epoch #9981 start
# Epoch #9981 end - Time elapsed: 552.93s
# Epoch #9982 start
# Epoch #9982 end - Time elapsed: 552.98s
# Epoch #9983 start
# Epoch #9983 end - Time elapsed: 553.03s
# Epoch #9984 start
# Epoch #9984 end - Time elapsed: 553.08s
# Epoch #9985 start
# Epoch #9985 end - Time elapsed: 553.13s
# Epoch #9986 start
# Epoch #9986 end - Time elapsed: 553.18s
# Epoch #9987 start
# Epoch #9987 end - Time elapsed: 553.24s
# Epoch #9988 start
# Epoch #9988 end - Time elapsed: 553.30s
# Epoch #9989 start
# Epoch #9989 end - Time elapsed: 553.35s
# Epoch #9990 start
# Epoch #9990 end - Time elapsed: 553.40s
# Epoch #9991 start
# Epoch #9991 end - Time elapsed: 553.45s
# Epoch #9992 start
# Epoch #9992 end - Time elapsed: 553.50s
# Epoch #9993 start
# Epoch #9993 end - Time elapsed: 553.55s
# Epoch #9994 start
# Epoch #9994 end - Time elapsed: 553.60s
# Epoch #9995 start
# Epoch #9995 end - Time elapsed: 553.65s
# Epoch #9996 start
# Epoch #9996 end - Time elapsed: 553.70s
# Epoch #9997 start
# Epoch #9997 end - Time elapsed: 553.75s
# Epoch #9998 start
# Epoch #9998 end - Time elapsed: 553.81s
# Epoch #9999 start
# Epoch #9999 end - Time elapsed: 553.85s
#
# Training completed in 553.85 seconds
# Vocabulary size: 1396 words
# Model saved to my_word2vec_model.model

# %%
vocab_size = len(model.wv.index_to_key)
print("Vocabulary Size:", vocab_size)
# Out:
# Vocabulary Size: 1396

# %%
all_words = model.wv.index_to_key
print("All Words in Vocabulary:", all_words[:10])
# Out:
# All Words in Vocabulary: ['the', 'and', 'to', 'it', 'she', 'of', 'said', 'you', 'in', 'was']

# %% [markdown]
# ### Word2VecEvaluator
#
# Defined a **`Word2VecEvaluator` class** that provides a suite of evaluation methods for Word2Vec models.
# It helps assess how well a trained model captures semantic relationships between words.
#
# #### Features
#
# - **`evaluate_word_similarity`**
#   Compares the model’s similarity scores for word pairs against human-annotated scores using *Spearman correlation*.
#
# - **`evaluate_analogies`**
#   Tests the model on analogy tasks (e.g., *king : queen :: man : woman*) and calculates accuracy.
#
# - **`evaluate_odd_one_out`**
#   Evaluates the model’s ability to detect the odd word in a group
#   (e.g., `["apple", "banana", "car", "orange"]`).
#
# - **`analyze_vocabulary_coverage`**
#   Checks how much of the vocabulary in given test texts is covered by the model and reports unknown words.
#
# - **`compare_with_baseline`**
#   Compares the model against a baseline Word2Vec model by analyzing similarity correlations on common words.

# %%
import numpy as np
from scipy.stats import spearmanr
from sklearn.metrics.pairwise import cosine_similarity

class Word2VecEvaluator:
    """Comprehensive evaluation suite for Word2Vec models"""

    def __init__(self, model):
        self.model = model
        self.wv = model.wv

    def evaluate_word_similarity(self, word_pairs_with_scores):
        """
        Evaluate model on word similarity datasets

        Args:
            word_pairs_with_scores: List of tuples (word1, word2, human_score)

        Returns:
            Spearman correlation with human judgments
        """

        model_similarities = []
        human_similarities = []

        for word1, word2, human_score in word_pairs_with_scores:
            try:
                model_sim = self.wv.similarity(word1, word2)
                model_similarities.append(model_sim)
                human_similarities.append(human_score)
            except KeyError:
                # Skip if words not in vocabulary
                continue

        if len(model_similarities) < 10:
            print("Warning: Too few valid word pairs for reliable evaluation")
            return None

        correlation, p_value = spearmanr(human_similarities, model_similarities)

        print(f"Word Similarity Evaluation:")
        print(f"Valid pairs: {len(model_similarities)}")
        print(f"Spearman correlation: {correlation:.4f}")
        print(f"P-value: {p_value:.4f}")

        return correlation

    def evaluate_analogies(self, analogy_dataset):
        """
        Evaluate model on word analogy tasks

        Args:
            analogy_dataset: List of tuples (word_a, word_b, word_c, word_d)
                           representing "word_a is to word_b as word_c is to word_d"

        Returns:
            Accuracy on analogy task
        """

        correct = 0
        total = 0
        #('king', 'queen', 'man', 'woman'),
        for word_a, word_b, word_c, expected_d in analogy_dataset:
            try:
                # Predict word_d
                result = self.wv.most_similar(
                    positive=[word_a, word_b],
                    negative=[word_c],
                    topn=1
                )

                predicted_d = result

                if predicted_d[0][0].lower() == expected_d.lower():
                    correct += 1

                total += 1

            except (KeyError, IndexError):
                # Skip if words not in vocabulary
                continue

        if total == 0:
            print("Warning: No valid analogies found")
            return 0

        accuracy = correct / total

        print(f"Analogy Evaluation:")
        print(f"Valid analogies: {total}")
        print(f"Correct predictions: {correct}")
        print(f"Accuracy: {accuracy:.4f}")

        return accuracy

    def evaluate_odd_one_out(self, word_groups):
        """
        Evaluate model's ability to identify odd words in groups

        Args:
            word_groups: List of lists, each containing words where one doesn't belong

        Returns:
            Accuracy on odd-one-out task
        """

        correct = 0
        total = 0

        for group in word_groups:
            if len(group) < 3:
                continue

            try:
                # Find the word that doesn't match others
                odd_word = self.wv.doesnt_match(group)

                # This is tricky - we need ground truth to evaluate properly
                # For now, just check if the model can identify AN odd word
                correct += 1  # Placeholder - you'd need labeled data
                total += 1

            except KeyError:
                continue

        if total == 0:
            return 0

        accuracy = correct / total

        print(f"Odd-One-Out Evaluation:")
        print(f"  Valid groups: {total}")
        print(f"  Accuracy: {accuracy:.4f}")

        return accuracy

    def analyze_vocabulary_coverage(self, test_texts):
        """
        Analyze how well model vocabulary covers test texts

        Args:
            test_texts: List of text strings

        Returns:
            Coverage statistics
        """

        vocab = set(self.wv.index_to_key)

        total_words = 0
        covered_words = 0
        unknown_words = set()

        for text in test_texts:
            words = text.lower().split()
            total_words += len(words)

            for word in words:
                if word in vocab:
                    covered_words += 1
                else:
                    unknown_words.add(word)

        coverage_ratio = covered_words / total_words if total_words > 0 else 0

        print(f"Vocabulary Coverage Analysis:")
        print(f"  Total words in test: {total_words}")
        print(f"  Covered words: {covered_words}")
        print(f"  Coverage ratio: {coverage_ratio:.4f}")
        print(f"  Unknown words: {len(unknown_words)}")

        return {
            'coverage_ratio': coverage_ratio,
            'unknown_words': list(unknown_words)[:20],  # Show first 20
            'total_unknown': len(unknown_words)
        }

    def compare_with_baseline(self, baseline_model, test_words):
        """
        Compare model performance with baseline model

        Args:
            baseline_model: Another Word2Vec model to compare against
            test_words: List of words to test

        Returns:
            Comparison statistics
        """

        common_words = []
        for word in test_words:
            if word in self.wv and word in baseline_model.wv:
                common_words.append(word)

        if len(common_words) < 10:
            print("Warning: Too few common words for reliable comparison")
            return None

        # Compare similarity patterns
        similarities = []

        for i, word1 in enumerate(common_words[:20]):  # Test subset
            for word2 in common_words[i+1:21]:  # Avoid too many comparisons

                sim1 = self.wv.similarity(word1, word2)
                sim2 = baseline_model.wv.similarity(word1, word2)

                similarities.append((sim1, sim2))

        model_sims = [s for s in similarities]
        baseline_sims = [s for s in similarities]

        correlation, _ = spearmanr(model_sims, baseline_sims)

        print(f"Model Comparison:")
        print(f"  Common vocabulary: {len(common_words)}")
        print(f"  Similarity correlation: {correlation:.4f}")

        return correlation

# %%
# Example evaluation datasets
word_similarity_pairs = [
    ('king', 'queen', 8.5),
    ('man', 'woman', 8.3),
    ('car', 'automobile', 9.2),
    ('computer', 'laptop', 7.8),
    ('cat', 'dog', 6.1),
    ('happy', 'sad', 2.1),
]

analogy_examples = [
    ('king', 'queen', 'man', 'woman'),
    ('paris', 'france', 'london', 'england'),
    ('walking', 'walked', 'running', 'ran'),
    ('good', 'better', 'bad', 'worse'),
]

# Usage example
evaluator = Word2VecEvaluator(model)
sim_score = evaluator.evaluate_word_similarity(word_similarity_pairs)
analogy_score = evaluator.evaluate_analogies(analogy_examples)
# Out:
# Warning: Too few valid word pairs for reliable evaluation
# Analogy Evaluation:
# Valid analogies: 3
# Correct predictions: 0
# Accuracy: 0.0000

# %%
word = "alice"
if word in model.wv:
    similar_words = model.wv.most_similar(word, topn=10)
    print(f"Most similar words to '{word}':")
    for similar_word, similarity in similar_words:
        print(f"{similar_word}: {similarity}")
else:
    print("Word is not in the vocabulary.")
# Out:
# Most similar words to 'alice':
# she: 0.6182680130004883
# king: 0.4920527935028076
# dormouse: 0.4626016914844513
# pig: 0.4381174147129059
# it: 0.43195730447769165
# he: 0.40746310353279114
# mouse: 0.3474424183368683
# snail: 0.34479963779449463
# sulkily: 0.3345183730125427
# thoughtfully: 0.3293803632259369

# %%
model.wv.similarity('king', 'man')
# Out:
# 0.41290423
